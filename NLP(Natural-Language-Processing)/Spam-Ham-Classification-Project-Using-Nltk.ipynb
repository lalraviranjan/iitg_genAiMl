# %% [markdown]
# # Spam-Ham Classification Project

# %%
import pandas as pd

# %%
df = pd.read_csv('spam.csv',encoding="ISO-8859-1")
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.drop(columns=['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], inplace=True)
df.rename(columns={"v1": "label", "v2": "message"}, inplace=True)
df.head()
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
# The re module in Python stands for Regular Expressions and is used for pattern matching and text processing.
import re
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\lalra\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
ss = SnowballStemmer('english')

# %% [markdown]
# 1. **Removing special characters & numbers** using `re.sub(r"[^a-zA-Z\s]", "", df['message'][i])`.
# 2. **Converting text to lowercase** with `.lower()`.
# 3. **Splitting text into words** using `.split()`.
# 4. **Applying stemming** (`port_stem(word)`) to reduce words to their root form.
# 5. **Removing stopwords** using `stopwords.words('english')`.
# 6. **Joining words back into a sentence** using `' '.join(review)`.

# %%
corpus = []
for i in range(0, len(df)):
    review = re.sub(r"[^a-zA-Z\s]", "", df['message'][i])
    review = review.lower()
    review = review.split()
    review = [ss.stem(word) for word in review if word not in stopwords.words('english')]
    review = ' '.join(review)
    corpus.append(review)

# %%
# Our depndent feature is label - spam/ham
Y = pd.get_dummies(df['label']).astype(int)

# %%
Y
# Out:
#       ham  spam
# 0       1     0
# 1       1     0
# 2       0     1
# 3       1     0
# 4       1     0
# ...   ...   ...
# 5567    0     1
# 5568    1     0
# 5569    1     0
# 5570    1     0
# 5571    1     0
#
# [5572 rows x 2 columns]

# %%
Y = Y.iloc[:,0].values
Y
# Out:
# array([1, 1, 0, ..., 1, 1, 1], shape=(5572,))

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(corpus,Y, test_size=0.20)

# %%
import sklearn
from sklearn.feature_extraction.text import CountVectorizer
# Initialize CountVectorizer with a vocabulary size limit of 100 unique words
# binary=True means each word presence is represented as 0 or 1 (instead of actual word counts)
cv = CountVectorizer(max_features=100, binary=True)

# %%
# Fit and transform the 'corpus' into a Bag of Words (BoW) representation
# X_train is Independent features
X_train = cv.fit_transform(X_train).toarray()
X_test = cv.transform(X_test).toarray()

# %%
# 100 words with frquency
cv.vocabulary_
# Out:
# {'im': np.int64(33),
#  'last': np.int64(35),
#  'night': np.int64(54),
#  'today': np.int64(84),
#  'day': np.int64(12),
#  'love': np.int64(41),
#  'msg': np.int64(50),
#  'repli': np.int64(65),
#  'stop': np.int64(75),
#  'would': np.int64(97),
#  'didnt': np.int64(14),
#  'know': np.int64(34),
#  'need': np.int64(52),
#  'got': np.int64(25),
#  'lor': np.int64(40),
#  'one': np.int64(58),
#  'time': np.int64(83),
#  'get': np.int64(21),
#  'back': np.int64(3),
#  'miss': np.int64(47),
#  'alreadi': np.int64(0),
#  'ask': np.int64(1),
#  'hi': np.int64(29),
#  'babe': np.int64(2),
#  'like': np.int64(39),
#  'sorri': np.int64(73),
#  'realli': np.int64(64),
#  'see': np.int64(69),
#  'tomorrow': np.int64(85),
#  'call': np.int64(4),
#  'ill': np.int64(32),
#  'text': np.int64(78),
#  'think': np.int64(82),
#  'work': np.int64(96),
#  'pleas': np.int64(61),
#  'come': np.int64(9),
#  'said': np.int64(67),
#  'ok': np.int64(57),
#  'home': np.int64(30),
#  'sleep': np.int64(72),
#  'good': np.int64(24),
#  'pls': np.int64(62),
#  'send': np.int64(70),
#  'da': np.int64(11),
#  'go': np.int64(23),
#  'meet': np.int64(44),
#  'happi': np.int64(27),
#  'ur': np.int64(88),
#  'well': np.int64(94),
#  'tell': np.int64(77),
#  'phone': np.int64(59),
#  'feel': np.int64(17),
#  'thing': np.int64(81),
#  'give': np.int64(22),
#  'take': np.int64(76),
#  'dont': np.int64(15),
#  'make': np.int64(43),
#  'morn': np.int64(49),
#  'thank': np.int64(79),
#  'say': np.int64(68),
#  'later': np.int64(36),
#  'wait': np.int64(89),
#  'free': np.int64(19),
#  'week': np.int64(93),
#  'even': np.int64(16),
#  'friend': np.int64(20),
#  'want': np.int64(90),
#  'much': np.int64(51),
#  'tri': np.int64(86),
#  'new': np.int64(53),
#  'great': np.int64(26),
#  'pick': np.int64(60),
#  'number': np.int64(55),
#  'yeah': np.int64(98),
#  'hey': np.int64(28),
#  'cant': np.int64(5),
#  'care': np.int64(6),
#  'still': np.int64(74),
#  'contact': np.int64(10),
#  'prize': np.int64(63),
#  'claim': np.int64(8),
#  'min': np.int64(46),
#  'win': np.int64(95),
#  'wat': np.int64(91),
#  'leav': np.int64(37),
#  'find': np.int64(18),
#  'oh': np.int64(56),
#  'way': np.int64(92),
#  'that': np.int64(80),
#  'mobil': np.int64(48),
#  'yes': np.int64(99),
#  'servic': np.int64(71),
#  'dear': np.int64(13),
#  'hope': np.int64(31),
#  'ltgt': np.int64(42),
#  'let': np.int64(38),
#  'txt': np.int64(87),
#  'cash': np.int64(7),
#  'right': np.int64(66),
#  'messag': np.int64(45)}

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
spam_detect_model = MultinomialNB().fit(X_train, Y_train)

# %%
spam_detect_model
# Out:
# MultinomialNB()

# %%
y_pred = spam_detect_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report

# %%
accuracy_score(Y_test, y_pred)
# Out:
# 0.9542600896860987

# %%
print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.74      0.81       150
#            1       0.96      0.99      0.97       965
#
#     accuracy                           0.95      1115
#    macro avg       0.93      0.86      0.89      1115
# weighted avg       0.95      0.95      0.95      1115

# %% [markdown]
# ## Spam Ham using - TF-IDF Model

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tf_v = TfidfVectorizer(max_features=2500, ngram_range=(1,2))

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(corpus,Y, test_size=0.20)

# %%
X_train = tf_v.fit_transform(X_train)
X_test = tf_v.transform(X_test)

# %%
from sklearn.naive_bayes import MultinomialNB
spam_tfidf_model = MultinomialNB().fit(X_train, Y_train)

# %%
tf_v.vocabulary_
# Out:
# {'pick': np.int64(1584),
#  'ur': np.int64(2234),
#  'fone': np.int64(724),
#  'sorri': np.int64(1953),
#  'msg': np.int64(1394),
#  'yar': np.int64(2451),
#  'lor': np.int64(1225),
#  'poor': np.int64(1634),
#  'thing': np.int64(2107),
#  'one': np.int64(1504),
#  'night': np.int64(1449),
#  'tmr': np.int64(2141),
#  'ull': np.int64(2220),
#  'brand': np.int64(215),
#  'new': np.int64(1436),
#  'room': np.int64(1775),
#  'sleep': np.int64(1914),
#  'yar lor': np.int64(2452),
#  'let': np.int64(1176),
#  'send': np.int64(1839),
#  'free': np.int64(735),
#  'messag': np.int64(1319),
#  'see': np.int64(1827),
#  'send free': np.int64(1842),
#  'send messag': np.int64(1844),
#  'think': np.int64(2108),
#  'chennai': np.int64(343),
#  'well': np.int64(2361),
#  'settl': np.int64(1864),
#  'sure': np.int64(2041),
#  'understand': np.int64(2223),
#  'wine': np.int64(2392),
#  'good': np.int64(830),
#  'idea': np.int64(995),
#  'yeah': np.int64(2454),
#  'wouldnt': np.int64(2428),
#  'leav': np.int64(1163),
#  'hour': np.int64(973),
#  'least': np.int64(1162),
#  'how': np.int64(977),
#  'sound': np.int64(1959),
#  'avail': np.int64(124),
#  'honey': np.int64(960),
#  'pls': np.int64(1609),
#  'find': np.int64(705),
#  'much': np.int64(1401),
#  'sell': np.int64(1837),
#  'predict': np.int64(1650),
#  'nigeria': np.int64(1448),
#  'mani': np.int64(1285),
#  'time': np.int64(2129),
#  'use': np.int64(2267),
#  'import': np.int64(1042),
#  'repli': np.int64(1742),
#  'monday': np.int64(1370),
#  'mani time': np.int64(1286),
#  'time use': np.int64(2135),
#  'hi': np.int64(931),
#  'wish': np.int64(2395),
#  'next': np.int64(1443),
#  'week': np.int64(2347),
#  'give': np.int64(803),
#  'full': np.int64(764),
#  'next week': np.int64(1444),
#  'aint': np.int64(40),
#  'gonna': np.int64(829),
#  'tough': np.int64(2170),
#  'ill': np.int64(1000),
#  'darren': np.int64(488),
#  'say': np.int64(1807),
#  'dat': np.int64(489),
#  'meet': np.int64(1309),
#  'da': np.int64(479),
#  'ge': np.int64(783),
#  'den': np.int64(514),
#  'dun': np.int64(579),
#  'dinner': np.int64(531),
#  'cos': np.int64(434),
#  'later': np.int64(1145),
#  'xy': np.int64(2446),
#  'feel': np.int64(689),
#  'lunch': np.int64(1263),
#  'da ge': np.int64(480),
#  'watch': np.int64(2333),
#  'nd': np.int64(1422),
#  'im': np.int64(1013),
#  'bed': np.int64(162),
#  'sweet': np.int64(2047),
#  'dream': np.int64(571),
#  'miss': np.int64(1342),
#  'sweet dream': np.int64(2048),
#  'serv': np.int64(1857),
#  'stay': np.int64(1991),
#  'dad': np.int64(481),
#  'alon': np.int64(51),
#  'also': np.int64(56),
#  'cbe': np.int64(317),
#  'pay': np.int64(1556),
#  'hey': np.int64(927),
#  'sis': np.int64(1905),
#  'huh': np.int64(985),
#  'need': np.int64(1427),
#  'detail': np.int64(516),
#  'onlin': np.int64(1510),
#  'job': np.int64(1088),
#  'man': np.int64(1281),
#  'teach': np.int64(2066),
#  'say hi': np.int64(1810),
#  'aight': np.int64(38),
#  'take': np.int64(2051),
#  'ten': np.int64(2076),
#  'year': np.int64(2460),
#  'shower': np.int64(1886),
#  'what': np.int64(2371),
#  'plan': np.int64(1595),
#  'sms': np.int64(1926),
#  'auction': np.int64(121),
#  'nokia': np.int64(1453),
#  'get': np.int64(788),
#  'win': np.int64(2387),
#  'part': np.int64(1549),
#  'hgsuiteland': np.int64(929),
#  'rowwjhl': np.int64(1780),
#  'nokia get': np.int64(1455),
#  'get win': np.int64(798),
#  'win free': np.int64(2389),
#  'free auction': np.int64(736),
#  'auction take': np.int64(122),
#  'take part': np.int64(2053),
#  'part send': np.int64(1550),
#  'send nokia': np.int64(1845),
#  'nokia hgsuiteland': np.int64(1456),
#  'hgsuiteland rowwjhl': np.int64(930),
#  'day': np.int64(492),
#  'gd': np.int64(782),
#  'luck': np.int64(1261),
#  'exam': np.int64(656),
#  'know': np.int64(1119),
#  'bring': np.int64(219),
#  'money': np.int64(1371),
#  'ive': np.int64(1076),
#  'school': np.int64(1814),
#  'rent': np.int64(1739),
#  'stuff': np.int64(2017),
#  'like': np.int64(1188),
#  'that': np.int64(2101),
#  'help': np.int64(925),
#  'friend': np.int64(754),
#  'pay rent': np.int64(1558),
#  'class': np.int64(361),
#  'pm': np.int64(1616),
#  'darl': np.int64(486),
#  'hope': np.int64(962),
#  'ok': np.int64(1490),
#  'coffe': np.int64(375),
#  'cant': np.int64(289),
#  'late': np.int64(1144),
#  'tomorrow': np.int64(2153),
#  'place': np.int64(1594),
#  'alway': np.int64(57),
#  'jus': np.int64(1096),
#  'true': np.int64(2184),
#  'realli': np.int64(1718),
#  'havent': np.int64(908),
#  'done': np.int64(549),
#  'anyth': np.int64(78),
#  'yet': np.int64(2473),
#  'cos im': np.int64(435),
#  'im realli': np.int64(1028),
#  'sign': np.int64(1893),
#  'matur': np.int64(1298),
#  'start': np.int64(1987),
#  'big': np.int64(174),
#  'actual': np.int64(14),
#  'small': np.int64(1921),
#  'nice': np.int64(1446),
#  'even': np.int64(641),
#  'bslvyl': np.int64(223),
#  'dear': np.int64(500),
#  'voucher': np.int64(2300),
#  'holder': np.int64(950),
#  'claim': np.int64(354),
#  'offer': np.int64(1481),
#  'pc': np.int64(1559),
#  'pleas': np.int64(1602),
#  'go': np.int64(807),
#  'tscs': np.int64(2189),
#  'appli': np.int64(87),
#  'dear voucher': np.int64(501),
#  'voucher holder': np.int64(2301),
#  'holder claim': np.int64(951),
#  'claim week': np.int64(360),
#  'week offer': np.int64(2353),
#  'offer pc': np.int64(1484),
#  'pleas go': np.int64(1605),
#  'tscs appli': np.int64(2190),
#  'got': np.int64(843),
#  'lol': np.int64(1215),
#  'shes': np.int64(1875),
#  'girl': np.int64(802),
#  'world': np.int64(2420),
#  'right': np.int64(1765),
#  'tri': np.int64(2179),
#  'come': np.int64(387),
#  'come pick': np.int64(391),
#  'wnt': np.int64(2410),
#  'buy': np.int64(236),
#  'car': np.int64(296),
#  'vri': np.int64(2302),
#  'hv': np.int64(989),
#  'ltgt': np.int64(1251),
#  'sourc': np.int64(1961),
#  'dis': np.int64(535),
#  'amt': np.int64(66),
#  'prob': np.int64(1670),
#  'truth': np.int64(2187),
#  'natur': np.int64(1419),
#  'happi': np.int64(897),
#  'valentin': np.int64(2273),
#  'advanc': np.int64(23),
#  'valentin day': np.int64(2274),
#  'urgent': np.int64(2259),
#  'costa': np.int64(439),
#  'del': np.int64(507),
#  'sol': np.int64(1932),
#  'holiday': np.int64(952),
#  'await': np.int64(127),
#  'collect': np.int64(379),
#  'call': np.int64(247),
#  'toclaim': np.int64(2142),
#  'sae': np.int64(1791),
#  'tc': np.int64(2058),
#  'pobox': np.int64(1625),
#  'stockport': np.int64(1998),
#  'skxh': np.int64(1910),
#  'costpm': np.int64(441),
#  'maxmin': np.int64(1301),
#  'costa del': np.int64(440),
#  'del sol': np.int64(508),
#  'sol holiday': np.int64(1933),
#  'holiday await': np.int64(953),
#  'await collect': np.int64(128),
#  'collect call': np.int64(380),
#  'call toclaim': np.int64(269),
#  'toclaim sae': np.int64(2143),
#  'sae tc': np.int64(1792),
#  'tc pobox': np.int64(2059),
#  'pobox stockport': np.int64(1626),
#  'stockport skxh': np.int64(1999),
#  'skxh costpm': np.int64(1911),
#  'costpm maxmin': np.int64(442),
#  'want': np.int64(2318),
#  'latest': np.int64(1148),
#  'video': np.int64(2284),
#  'handset': np.int64(894),
#  'anytim': np.int64(80),
#  'network': np.int64(1431),
#  'min': np.int64(1328),
#  'half': np.int64(890),
#  'price': np.int64(1658),
#  'line': np.int64(1194),
#  'rental': np.int64(1740),
#  'deliveri': np.int64(511),
#  'video handset': np.int64(2285),
#  'anytim network': np.int64(81),
#  'network min': np.int64(1432),
#  'min half': np.int64(1329),
#  'half price': np.int64(892),
#  'price line': np.int64(1659),
#  'line rental': np.int64(1196),
#  'repli call': np.int64(1743),
#  'call deliveri': np.int64(254),
#  'deliveri tomorrow': np.int64(512),
#  'talk': np.int64(2056),
#  'like ltgt': np.int64(1192),
#  'ugh': np.int64(2217),
#  'ppl': np.int64(1645),
#  'dont': np.int64(550),
#  'random': np.int64(1700),
#  'mean': np.int64(1304),
#  'paid': np.int64(1543),
#  'last': np.int64(1139),
#  'semest': np.int64(1838),
#  'thank': np.int64(2098),
#  'happi new': np.int64(900),
#  'new year': np.int64(1441),
#  'let know': np.int64(1178),
#  'secret': np.int64(1823),
#  'admir': np.int64(19),
#  'look': np.int64(1220),
#  'make': np.int64(1275),
#  'contact': np.int64(411),
#  'ufind': np.int64(2215),
#  'rreveal': np.int64(1782),
#  'specialcal': np.int64(1971),
#  'secret admir': np.int64(1824),
#  'admir look': np.int64(20),
#  'look make': np.int64(1223),
#  'make contact': np.int64(1276),
#  'contact ufind': np.int64(421),
#  'ufind rreveal': np.int64(2216),
#  'rreveal think': np.int64(1783),
#  'think ur': np.int64(2111),
#  'ur specialcal': np.int64(2255),
#  'compani': np.int64(397),
#  'food': np.int64(725),
#  'home': np.int64(958),
#  'within': np.int64(2400),
#  'dude': np.int64(577),
#  'point': np.int64(1628),
#  'thought': np.int64(2117),
#  'fli': np.int64(718),
#  'almost': np.int64(50),
#  'babi': np.int64(139),
#  'back': np.int64(140),
#  'work': np.int64(2416),
#  'didnt': np.int64(519),
#  'piss': np.int64(1591),
#  'phone': np.int64(1576),
#  'today': np.int64(2144),
#  'xxx': np.int64(2444),
#  'ive got': np.int64(1077),
#  'want see': np.int64(2323),
#  'give call': np.int64(804),
#  'bill': np.int64(175),
#  'respons': np.int64(1756),
#  'nah': np.int64(1413),
#  'wednesday': np.int64(2345),
#  'bag': np.int64(143),
#  'special': np.int64(1967),
#  'rose': np.int64(1777),
#  'ladi': np.int64(1128),
#  'info': np.int64(1053),
#  'kiss': np.int64(1116),
#  'winner': np.int64(2393),
#  'ave': np.int64(125),
#  'select': np.int64(1834),
#  'receiv': np.int64(1722),
#  'cash': np.int64(304),
#  'flight': np.int64(719),
#  'inc': np.int64(1046),
#  'speak': np.int64(1965),
#  'live': np.int64(1202),
#  'oper': np.int64(1516),
#  'pmin': np.int64(1617),
#  'special select': np.int64(1970),
#  'select receiv': np.int64(1835),
#  'receiv cash': np.int64(1724),
#  'cash holiday': np.int64(308),
#  'holiday flight': np.int64(955),
#  'flight inc': np.int64(720),
#  'inc speak': np.int64(1047),
#  'speak live': np.int64(1966),
#  'live oper': np.int64(1204),
#  'oper claim': np.int64(1517),
#  'coupl': np.int64(447),
#  'minut': np.int64(1336),
#  'track': np.int64(2173),
#  'yeah sure': np.int64(2458),
#  'hes': np.int64(926),
#  'sad': np.int64(1789),
#  'keep': np.int64(1102),
#  'touch': np.int64(2169),
#  'skype': np.int64(1912),
#  'keep touch': np.int64(1104),
#  'chang': np.int64(330),
#  'report': np.int64(1749),
#  'alreadi': np.int64(53),
#  'made': np.int64(1269),
#  'previous': np.int64(1657),
#  'comin': np.int64(394),
#  'close': np.int64(366),
#  'ill call': np.int64(1002),
#  'call im': np.int64(258),
#  'life': np.int64(1183),
#  'brought': np.int64(222),
#  'sun': np.int64(2030),
#  'warm': np.int64(2327),
#  'heart': np.int64(916),
#  'put': np.int64(1687),
#  'constant': np.int64(410),
#  'smile': np.int64(1922),
#  'face': np.int64(669),
#  'love': np.int64(1233),
#  'care': np.int64(298),
#  'make feel': np.int64(1277),
#  'boy': np.int64(213),
#  'dunno': np.int64(584),
#  'said': np.int64(1795),
#  'us': np.int64(2266),
#  'yup': np.int64(2496),
#  'reach': np.int64(1709),
#  'come home': np.int64(389),
#  'go lor': np.int64(814),
#  'aiyah': np.int64(44),
#  'lar': np.int64(1136),
#  'suppos': np.int64(2039),
#  'couldnt': np.int64(445),
#  'still': np.int64(1994),
#  'town': np.int64(2172),
#  'though': np.int64(2116),
#  'mr': np.int64(1389),
#  'ipod': np.int64(1067),
#  'excit': np.int64(659),
#  'prize': np.int64(1664),
#  'soon': np.int64(1950),
#  'eye': np.int64(667),
#  'mobil': np.int64(1352),
#  'visit': np.int64(2294),
#  'ur mobil': np.int64(2248),
#  'anymor': np.int64(76),
#  'tonight': np.int64(2161),
#  'cri': np.int64(460),
#  'enough': np.int64(622),
#  'im gonna': np.int64(1024),
#  'dont want': np.int64(562),
#  'want talk': np.int64(2325),
#  'guy': np.int64(881),
#  'hasnt': np.int64(905),
#  'sinc': np.int64(1898),
#  'break': np.int64(216),
#  'fuck': np.int64(763),
#  'doesnt': np.int64(544),
#  'without': np.int64(2402),
#  'til': np.int64(2127),
#  'know one': np.int64(1123),
#  'final': np.int64(703),
#  'doubl': np.int64(565),
#  'txts': np.int64(2211),
#  'orang': np.int64(1523),
#  'motorola': np.int64(1383),
#  'sonyericsson': np.int64(1948),
#  'bluetooth': np.int64(194),
#  'mobileupd': np.int64(1362),
#  'doubl min': np.int64(566),
#  'min txts': np.int64(1331),
#  'orang tariff': np.int64(1525),
#  'latest motorola': np.int64(1151),
#  'motorola sonyericsson': np.int64(1384),
#  'sonyericsson nokia': np.int64(1949),
#  'free call': np.int64(738),
#  'call mobileupd': np.int64(263),
#  'england': np.int64(619),
#  'news': np.int64(1442),
#  'txt': np.int64(2199),
#  'nation': np.int64(1417),
#  'team': np.int64(2067),
#  'eg': np.int64(599),
#  'dont miss': np.int64(558),
#  'lesson': np.int64(1175),
#  'gym': np.int64(882),
#  'found': np.int64(732),
#  'cheap': np.int64(339),
#  'somewher': np.int64(1944),
#  'isnt': np.int64(1072),
#  'test': np.int64(2082),
#  'number': np.int64(1474),
#  'tell': np.int64(2072),
#  'wait': np.int64(2305),
#  'quick': np.int64(1691),
#  'tell ur': np.int64(2075),
#  'theyr': np.int64(2106),
#  'drive': np.int64(574),
#  'inch': np.int64(1048),
#  'snow': np.int64(1929),
#  'haha': np.int64(886),
#  'awesom': np.int64(136),
#  'haha awesom': np.int64(887),
#  'convey': np.int64(424),
#  'regard': np.int64(1730),
#  'boo': np.int64(199),
#  'tick': np.int64(2122),
#  'babe': np.int64(137),
#  'tick tick': np.int64(2123),
#  'morn': np.int64(1378),
#  'plz': np.int64(1615),
#  'sir': np.int64(1903),
#  'good morn': np.int64(837),
#  'call sir': np.int64(268),
#  'post': np.int64(1640),
#  'must': np.int64(1410),
#  'text': np.int64(2083),
#  'read': np.int64(1712),
#  'wiv': np.int64(2403),
#  'hello': np.int64(924),
#  'end': np.int64(613),
#  'bless': np.int64(185),
#  'neva': np.int64(1434),
#  'mate': np.int64(1295),
#  'fren': np.int64(751),
#  'wan': np.int64(2311),
#  'ah': np.int64(34),
#  'muz': np.int64(1411),
#  'rite': np.int64(1771),
#  'dun wan': np.int64(583),
#  'wan meet': np.int64(2314),
#  'issu': np.int64(1073),
#  'yup im': np.int64(2497),
#  'time come': np.int64(2130),
#  'come later': np.int64(390),
#  'yep': np.int64(2463),
#  'fine': np.int64(707),
#  'ice': np.int64(993),
#  'age': np.int64(32),
#  'cool': np.int64(430),
#  'princess': np.int64(1661),
#  'cover': np.int64(449),
#  'hot': np.int64(970),
#  'cum': np.int64(466),
#  'that cool': np.int64(2102),
#  'deep': np.int64(505),
#  'sigh': np.int64(1891),
#  'surpris': np.int64(2045),
#  'gone': np.int64(828),
#  'net': np.int64(1430),
#  'cafe': np.int64(242),
#  'happen': np.int64(896),
#  'pls call': np.int64(1610),
#  'sunni': np.int64(2032),
#  'weather': np.int64(2342),
#  'great': np.int64(858),
#  'amp': np.int64(59),
#  'success': np.int64(2024),
#  'morn dear': np.int64(1380),
#  'seem': np.int64(1832),
#  'gettin': np.int64(799),
#  'ure': np.int64(2258),
#  'mths': np.int64(1397),
#  'camera': np.int64(282),
#  'updat': np.int64(2232),
#  'orstoptxt': np.int64(1533),
#  'mths half': np.int64(1398),
#  'price orang': np.int64(1660),
#  'orang line': np.int64(1524),
#  'latest camera': np.int64(1149),
#  'camera phone': np.int64(285),
#  'phone free': np.int64(1579),
#  'free phone': np.int64(744),
#  'brother': np.int64(221),
#  'gr': np.int64(852),
#  'miss call': np.int64(1345),
#  'gr day': np.int64(853),
#  'forward': np.int64(731),
#  'weed': np.int64(2346),
#  'hungri': np.int64(986),
#  'smth': np.int64(1928),
#  'bit': np.int64(181),
#  'sort': np.int64(1958),
#  'unless': np.int64(2224),
#  'there': np.int64(2105),
#  'dont know': np.int64(555),
#  'twice': np.int64(2197),
#  'peopl': np.int64(1561),
#  'spend': np.int64(1973),
#  'spent': np.int64(1974),
#  'keep smile': np.int64(1103),
#  'bad': np.int64(142),
#  'rememb': np.int64(1736),
#  'felt': np.int64(694),
#  'reason': np.int64(1720),
#  'ese': np.int64(634),
#  'saw': np.int64(1806),
#  'captain': np.int64(295),
#  'parti': np.int64(1551),
#  'award': np.int64(130),
#  'bonus': np.int64(197),
#  'caller': np.int64(273),
#  'attempt': np.int64(117),
#  'urgent mobil': np.int64(2261),
#  'mobil award': np.int64(1353),
#  'award bonus': np.int64(131),
#  'bonus caller': np.int64(198),
#  'caller prize': np.int64(275),
#  'prize nd': np.int64(1668),
#  'nd attempt': np.int64(1423),
#  'attempt contact': np.int64(118),
#  'contact call': np.int64(412),
#  'rock': np.int64(1773),
#  'bore': np.int64(202),
#  'speed': np.int64(1972),
#  'date': np.int64(490),
#  'em': np.int64(607),
#  'chat': np.int64(337),
#  'poboxwwq': np.int64(1627),
#  'pmsg': np.int64(1619),
#  'dont like': np.int64(556),
#  'nobodi': np.int64(1451),
#  'name': np.int64(1415),
#  'stori': np.int64(2011),
#  'add': np.int64(16),
#  'yahoo': np.int64(2448),
#  'legal': np.int64(1168),
#  'famili': np.int64(674),
#  'readi': np.int64(1714),
#  'ask': np.int64(107),
#  'pick phone': np.int64(1585),
#  'first': np.int64(710),
#  'stock': np.int64(1997),
#  'winner special': np.int64(2394),
#  'could': np.int64(443),
#  'carlo': np.int64(301),
#  'anybodi': np.int64(75),
#  'els': np.int64(604),
#  'could get': np.int64(444),
#  'extra': np.int64(665),
#  'yes': np.int64(2466),
#  'mobil mths': np.int64(1358),
#  'mths updat': np.int64(1399),
#  'updat latest': np.int64(2233),
#  'glad': np.int64(806),
#  'total': np.int64(2168),
#  'well im': np.int64(2363),
#  'im glad': np.int64(1022),
#  'angri': np.int64(68),
#  'bugi': np.int64(230),
#  'oso': np.int64(1535),
#  'near': np.int64(1426),
#  'wat': np.int64(2330),
#  'never': np.int64(1435),
#  'invit': np.int64(1062),
#  'littl': np.int64(1201),
#  'ahead': np.int64(36),
#  'good time': np.int64(839),
#  'case': np.int64(303),
#  'shall': np.int64(1869),
#  'an': np.int64(67),
#  'arrang': np.int64(101),
#  'water': np.int64(2335),
#  'log': np.int64(1211),
#  'yo': np.int64(2477),
#  'im tri': np.int64(1035),
#  'tri get': np.int64(2181),
#  'id': np.int64(994),
#  'tv': np.int64(2194),
#  'someth': np.int64(1940),
#  'im bore': np.int64(1016),
#  'thought id': np.int64(2118),
#  'black': np.int64(183),
#  'shirt': np.int64(1877),
#  'blue': np.int64(191),
#  'thk': np.int64(2113),
#  'experi': np.int64(663),
#  'god': np.int64(821),
#  'ur life': np.int64(2244),
#  'good day': np.int64(833),
#  'day give': np.int64(495),
#  'whatev': np.int64(2372),
#  'im come': np.int64(1018),
#  'whatev want': np.int64(2373),
#  'hous': np.int64(974),
#  'im leav': np.int64(1026),
#  'leav hous': np.int64(1164),
#  'lei': np.int64(1170),
#  'mum': np.int64(1402),
#  'lazi': np.int64(1157),
#  'dunno lei': np.int64(585),
#  'coz': np.int64(450),
#  'guess': np.int64(878),
#  'anyth lor': np.int64(79),
#  'oredi': np.int64(1530),
#  'juz': np.int64(1098),
#  'rem': np.int64(1734),
#  'tone': np.int64(2155),
#  'mob': np.int64(1350),
#  'everi': np.int64(646),
#  'st': np.int64(1981),
#  'txtin': np.int64(2207),
#  'ptone': np.int64(1679),
#  'hl': np.int64(942),
#  'nokia tone': np.int64(1460),
#  'tone ur': np.int64(2160),
#  'ur mob': np.int64(2247),
#  'mob everi': np.int64(1351),
#  'everi week': np.int64(648),
#  'week txt': np.int64(2355),
#  'st tone': np.int64(1982),
#  'tone free': np.int64(2158),
#  'free get': np.int64(741),
#  'get txtin': np.int64(796),
#  'txtin tell': np.int64(2208),
#  'ur friend': np.int64(2239),
#  'friend ptone': np.int64(756),
#  'ptone repli': np.int64(1680),
#  'repli hl': np.int64(1746),
#  'hl info': np.int64(943),
#  'funni': np.int64(767),
#  'fact': np.int64(671),
#  'hw': np.int64(990),
#  'choos': np.int64(350),
#  'wife': np.int64(2384),
#  'weekend': np.int64(2356),
#  'ill tell': np.int64(1010),
#  'clean': np.int64(362),
#  'lmao': np.int64(1205),
#  'pic': np.int64(1583),
#  'mon': np.int64(1369),
#  'goin': np.int64(827),
#  'cuz': np.int64(476),
#  'bus': np.int64(233),
#  'want go': np.int64(2321),
#  'feel like': np.int64(692),
#  'earth': np.int64(590),
#  'lose': np.int64(1227),
#  'ever': np.int64(644),
#  'quit': np.int64(1692),
#  'ex': np.int64(654),
#  'villag': np.int64(2293),
#  'pub': np.int64(1681),
#  'either': np.int64(602),
#  'anoth': np.int64(70),
#  'hospit': np.int64(969),
#  'finish': np.int64(709),
#  'decid': np.int64(503),
#  'left': np.int64(1167),
#  'goodmorn': np.int64(840),
#  'ltdecimalgt': np.int64(1250),
#  'goodmorn today': np.int64(841),
#  'today late': np.int64(2147),
#  'wil': np.int64(2386),
#  'unlimit': np.int64(2225),
#  'camcord': np.int64(278),
#  'call repli': np.int64(266),
#  'min unlimit': np.int64(1332),
#  'unlimit text': np.int64(2226),
#  'text free': np.int64(2087),
#  'free camcord': np.int64(739),
#  'camcord repli': np.int64(279),
#  'wk': np.int64(2404),
#  'servic': np.int64(1858),
#  'cost': np.int64(437),
#  'credit': np.int64(458),
#  'kick': np.int64(1109),
#  'enjoy': np.int64(621),
#  'uve': np.int64(2271),
#  'xchat': np.int64(2439),
#  'pmsgrcvdhgsuitelandsrowwjhl': np.int64(1621),
#  'ldn': np.int64(1158),
#  'yrs': np.int64(2492),
#  'uve invit': np.int64(2272),
#  'invit xchat': np.int64(1065),
#  'xchat final': np.int64(2440),
#  'final attempt': np.int64(704),
#  'contact txt': np.int64(420),
#  'txt chat': np.int64(2201),
#  'chat pmsgrcvdhgsuitelandsrowwjhl': np.int64(338),
#  'pmsgrcvdhgsuitelandsrowwjhl ldn': np.int64(1622),
#  'ldn yrs': np.int64(1159),
#  'anoth day': np.int64(71),
#  'account': np.int64(8),
#  'show': np.int64(1883),
#  'unredeem': np.int64(2227),
#  'identifi': np.int64(996),
#  'code': np.int64(372),
#  'expir': np.int64(664),
#  'show unredeem': np.int64(1885),
#  'unredeem point': np.int64(2228),
#  'claim call': np.int64(355),
#  'call identifi': np.int64(257),
#  'identifi code': np.int64(997),
#  'ya': np.int64(2447),
#  'vikki': np.int64(2292),
#  'vl': np.int64(2295),
#  'il': np.int64(999),
#  'ltgt min': np.int64(1256),
#  'euro': np.int64(639),
#  'kept': np.int64(1105),
#  'inform': np.int64(1054),
#  'result': np.int64(1758),
#  'daili': np.int64(484),
#  'unsubscrib': np.int64(2230),
#  'stop': np.int64(2001),
#  'menu': np.int64(1317),
#  'noon': np.int64(1464),
#  'might': np.int64(1325),
#  'earli': np.int64(588),
#  'might come': np.int64(1326),
#  'consid': np.int64(409),
#  'wall': np.int64(2310),
#  'shit': np.int64(1878),
#  'play': np.int64(1597),
#  'peac': np.int64(1560),
#  'high': np.int64(937),
#  'old': np.int64(1501),
#  'build': np.int64(231),
#  'fight': np.int64(698),
#  'oh': np.int64(1487),
#  'guarante': np.int64(868),
#  'land': np.int64(1130),
#  'valid': np.int64(2275),
#  'hrs': np.int64(981),
#  'mobil number': np.int64(1359),
#  'number award': np.int64(1475),
#  'award prize': np.int64(133),
#  'prize guarante': np.int64(1667),
#  'guarante call': np.int64(870),
#  'call land': np.int64(259),
#  'land line': np.int64(1131),
#  'line claim': np.int64(1195),
#  'claim valid': np.int64(359),
#  'valid hrs': np.int64(2276),
#  'last night': np.int64(1140),
#  'long': np.int64(1218),
#  'wat time': np.int64(2331),
#  'time go': np.int64(2132),
#  'hav': np.int64(907),
#  'wit': np.int64(2399),
#  'drop': np.int64(575),
#  'tear': np.int64(2068),
#  'lik': np.int64(1187),
#  'great weekend': np.int64(862),
#  'imma': np.int64(1040),
#  'definit': np.int64(506),
#  'ill let': np.int64(1008),
#  'know im': np.int64(1122),
#  'omg': np.int64(1502),
#  'one thing': np.int64(1508),
#  'budget': np.int64(229),
#  'player': np.int64(1599),
#  'rate': np.int64(1702),
#  'friday': np.int64(753),
#  'word': np.int64(2415),
#  'better': np.int64(171),
#  'gud': np.int64(873),
#  'mrng': np.int64(1390),
#  'gud mrng': np.int64(875),
#  'vote': np.int64(2299),
#  'sing': np.int64(1899),
#  'along': np.int64(52),
#  'link': np.int64(1197),
#  'mobil free': np.int64(1357),
#  'way': np.int64(2336),
#  'ur home': np.int64(2242),
#  'address': np.int64(18),
#  'stop text': np.int64(2009),
#  'txt stop': np.int64(2205),
#  'sent': np.int64(1850),
#  'score': np.int64(1815),
#  'research': np.int64(1754),
#  'joke': np.int64(1092),
#  'less': np.int64(1173),
#  'expens': np.int64(662),
#  'less expens': np.int64(1174),
#  'orchard': np.int64(1527),
#  'tri contact': np.int64(2180),
#  'contact repli': np.int64(418),
#  'video phone': np.int64(2286),
#  'phone anytim': np.int64(1577),
#  'forget': np.int64(728),
#  'studi': np.int64(2016),
#  'dont forget': np.int64(552),
#  'naughti': np.int64(1421),
#  'pix': np.int64(1592),
#  'sorri cant': np.int64(1954),
#  'laugh': np.int64(1155),
#  'alex': np.int64(49),
#  'turn': np.int64(2193),
#  'deal': np.int64(499),
#  'come ur': np.int64(393),
#  'longer': np.int64(1219),
#  'frnds': np.int64(762),
#  'charact': np.int64(331),
#  'dey': np.int64(517),
#  'best': np.int64(169),
#  'differ': np.int64(526),
#  'pin': np.int64(1590),
#  'abl': np.int64(1),
#  'notic': np.int64(1468),
#  'anyway': np.int64(82),
#  'vodafon': np.int64(2296),
#  'match': np.int64(1293),
#  'number end': np.int64(1476),
#  'receiv award': np.int64(1723),
#  'offici': np.int64(1486),
#  'poli': np.int64(1630),
#  'rington': np.int64(1768),
#  'colour': np.int64(383),
#  'flag': np.int64(714),
#  'yer': np.int64(2464),
#  'game': np.int64(772),
#  'optout': np.int64(1521),
#  'eng': np.int64(617),
#  'box': np.int64(209),
#  'wwx': np.int64(2438),
#  'get offici': np.int64(794),
#  'poli rington': np.int64(1631),
#  'rington colour': np.int64(1769),
#  'colour flag': np.int64(385),
#  'flag yer': np.int64(716),
#  'yer mobil': np.int64(2465),
#  'text tone': np.int64(2092),
#  'tone flag': np.int64(2157),
#  'flag optout': np.int64(715),
#  'optout txt': np.int64(1522),
#  'txt eng': np.int64(2202),
#  'eng stop': np.int64(618),
#  'stop box': np.int64(2002),
#  'box wwx': np.int64(212),
#  'ard': np.int64(92),
#  'rest': np.int64(1757),
#  'wake': np.int64(2308),
#  'welcom': np.int64(2360),
#  'joy': np.int64(1093),
#  'content': np.int64(422),
#  'mobil content': np.int64(1355),
#  'oki': np.int64(1500),
#  'your': np.int64(2487),
#  'text your': np.int64(2093),
#  'txting': np.int64(2209),
#  'im go': np.int64(1023),
#  'gave': np.int64(777),
#  'photo': np.int64(1582),
#  'regist': np.int64(1731),
#  'wanna': np.int64(2317),
#  'someon': np.int64(1936),
#  'wors': np.int64(2423),
#  'where': np.int64(2375),
#  'boytoy': np.int64(214),
#  'center': np.int64(323),
#  'futur': np.int64(768),
#  'okay': np.int64(1499),
#  'meant': np.int64(1305),
#  'yun': np.int64(2494),
#  'wana': np.int64(2316),
#  'except': np.int64(658),
#  'hr': np.int64(980),
#  'privat': np.int64(1662),
#  'statement': np.int64(1988),
#  'sim': np.int64(1895),
#  'privat account': np.int64(1663),
#  'account statement': np.int64(9),
#  'statement show': np.int64(1989),
#  'point call': np.int64(1629),
#  'wonder': np.int64(2412),
#  'wow': np.int64(2429),
#  'tm': np.int64(2140),
#  'whenev': np.int64(2374),
#  'mine': np.int64(1335),
#  'fri': np.int64(752),
#  'outsid': np.int64(1538),
#  'cut': np.int64(474),
#  'short': np.int64(1881),
#  'leh': np.int64(1169),
#  'fail': np.int64(672),
#  'din': np.int64(530),
#  'hair': np.int64(889),
#  'opt': np.int64(1520),
#  'name age': np.int64(1416),
#  'none': np.int64(1463),
#  'indian': np.int64(1052),
#  'version': np.int64(2280),
#  'kerala': np.int64(1106),
#  'version one': np.int64(2281),
#  'order': np.int64(1528),
#  'refer': np.int64(1728),
#  'charg': np.int64(332),
#  'arriv': np.int64(103),
#  'custom': np.int64(472),
#  'thank rington': np.int64(2099),
#  'rington order': np.int64(1770),
#  'order refer': np.int64(1529),
#  'refer number': np.int64(1729),
#  'mobil charg': np.int64(1354),
#  'charg tone': np.int64(334),
#  'tone arriv': np.int64(2156),
#  'arriv pleas': np.int64(104),
#  'pleas call': np.int64(1603),
#  'call custom': np.int64(253),
#  'custom servic': np.int64(473),
#  'sorri ill': np.int64(1956),
#  'call later': np.int64(261),
#  'chanc': np.int64(328),
#  'fantasi': np.int64(676),
#  'per': np.int64(1563),
#  'ntt': np.int64(1470),
#  'ltd': np.int64(1248),
#  'po': np.int64(1623),
#  'croydon': np.int64(462),
#  'cr': np.int64(452),
#  'wb': np.int64(2338),
#  'call per': np.int64(264),
#  'per min': np.int64(1565),
#  'min ntt': np.int64(1330),
#  'ntt ltd': np.int64(1471),
#  'ltd po': np.int64(1249),
#  'po box': np.int64(1624),
#  'box croydon': np.int64(210),
#  'croydon cr': np.int64(463),
#  'cr wb': np.int64(453),
#  'wb nation': np.int64(2339),
#  'nation rate': np.int64(1418),
#  'rate call': np.int64(1703),
#  'inclus': np.int64(1050),
#  'goto': np.int64(847),
#  'wwwcomuknet': np.int64(2434),
#  'login': np.int64(1213),
#  'ip': np.int64(1066),
#  'text credit': np.int64(2086),
#  'credit pls': np.int64(459),
#  'pls goto': np.int64(1612),
#  'goto wwwcomuknet': np.int64(848),
#  ...}

# %%
y_pred = spam_tfidf_model.predict(X_test)

# %%
print(accuracy_score(Y_test, y_pred))
# Out:
# 0.9704035874439462

# %%
print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.80      0.88       158
#            1       0.97      1.00      0.98       957
#
#     accuracy                           0.97      1115
#    macro avg       0.98      0.90      0.93      1115
# weighted avg       0.97      0.97      0.97      1115

# %% [markdown]
# #### Important for interview point of view to remember the steps
# 1. Preprocessing and Cleaning
# 2. Train test split
# 3. BOW and TF-IDF (Perform this after Train test split so that our model will have no information regarding our test data)
# 4. Trained our models

# %% [markdown]
# # Spam Ham classification using Word2vec and RandomwforestClassifier
#
# #### Colab - https://colab.research.google.com/drive/1DMK0Z3MM8D5st0-DdBmVdQFxTj8u-P0e#scrollTo=2EgUKwoih0-q
