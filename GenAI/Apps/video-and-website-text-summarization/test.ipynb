# %%
from pytube import YouTube

yt = YouTube("https://www.youtube.com/watch?v=6SO-8FcSkz4")
print(yt.title)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 from pytube import YouTube
#       3 yt = YouTube("https://www.youtube.com/watch?v=dQw4w9WgXcQ")
# ----> 4 print(yt.title)
#
# File c:\Users\lalra\anaconda3\envs\huggingface\Lib\site-packages\pytube\__main__.py:341, in YouTube.title(self)
#     338     return self._title
#     340 try:
# --> 341     self._title = self.vid_info['videoDetails']['title']
#     342 except KeyError:
#     343     # Check_availability will raise the correct exception in most cases
#     344     #  if it doesn't, ask for a report.
#     345     self.check_availability()
#
# File c:\Users\lalra\anaconda3\envs\huggingface\Lib\site-packages\pytube\__main__.py:246, in YouTube.vid_info(self)
#     242     return self._vid_info
#     244 innertube = InnerTube(use_oauth=self.use_oauth, allow_cache=self.allow_oauth_cache)
# ...
