# %% [markdown]
# ## Indian Banking and Finance Report-QA Chatbot: Using Langchain | PineCone | Redis | OpenAi

# %%
import os
from dotenv import load_dotenv
from functools import lru_cache

PINECONE_API_KEY = os.getenv("PINECONE_API_KEY")
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

load_dotenv()
# This is needed to enable LangSmith logging/tracing for chains, prompts, and LLM calls.
os.environ['LANGCHAIN_API_KEY'] = os.getenv('LANGCHAIN_API_KEY')

# Setting this to 'true' will start recording all your chain/agent/LLM activity for debugging and evaluation.
os.environ['LANGCHAIN_TRACING_V2'] = 'true'

# This helps organize and filter traces inside the LangSmith dashboard based on this project.
os.environ['Langchain_Project'] = os.getenv('LANGCHAIN_PROJECT')

# %% [markdown]
# ### Utilize OpenAi embeddings to convert text chunks into vectors

# %%
from langchain.embeddings import OpenAIEmbeddings

@lru_cache()
def get_embeddings():
    """
    Lazily load and cache the OpenAI Embeddings instance.
    Only initialized once per process.
    """
    return OpenAIEmbeddings(openai_api_key=os.getenv("OPENAI_API_KEY"))

embeddings = get_embeddings()
# Out:
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\4134011594.py:9: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import OpenAIEmbeddings``.
#   return OpenAIEmbeddings(openai_api_key=os.getenv("OPENAI_API_KEY"))

# %%
from langchain.chat_models import ChatOpenAI
@lru_cache()
def get_llm():
    """
    Lazily load and cache the LLM instance.
    Only initialized once per process.
    """
    return ChatOpenAI(
        temperature=0,
        model_name="gpt-3.5-turbo",
    )
    
llm = get_llm()
# Out:
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\2627125912.py:8: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import ChatOpenAI``.
#   return ChatOpenAI(

# %% [markdown]
# ### Load and Split documents into Chunks

# %%
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

loader = PyPDFLoader('India Banking and Finance Report 2024.pdf')
documents = loader.load()

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size= 800,
    chunk_overlap= 100,
    separators=["\n\n", "\n", ".", " ", ""]
)

text_docs = text_splitter.split_documents(documents)
# Add metadata for source type
for doc in text_docs:
    doc.metadata["source"] = "text"

text_docs[:5]
# Out:
# [Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe InDesign CC 2017 (Windows)', 'creationdate': '2024-11-13T13:26:09+05:30', 'moddate': '2024-12-02T14:37:36+05:30', 'trapped': '/False', 'source': 'text', 'total_pages': 248, 'page': 0, 'page_label': 'i'}, page_content='IBFR 2024 is published by Academic Foundation in association with NIBM, Pune and is available for purchase from Amazon\nNATIONAL INSTITUTE OF \nBANK MANAGEMENT\n(NIBM), PUNE\nINDIA BANKING \nAND FINANCE  \nREPORT 2024\nEdited by\nPARTHA RAY\nARINDAM BANDYOPADHYAY\nSANJAY BASU\nINR 1495 (Ind sub)\nUS$ 79.95 (overseas)\nISBN 978-93-327-0655-2\nINR 2595 (Ind sub)\nUS$ 89.95 (overseas)\nNATIONAL INSTITUTE OF \nBANK MANAGEMENT\n(NIBM), PUNEwww.nibmindia.org\nNIBM\nPARTHA RAY\nARINDAM BANDYOPADHYAYSANJAY BASU\nI\nBFR has become the flagship annual publication of NIBM \nPune eagerly awaited by the practitioners, experts, regula-\ntors and students of financial services and insurance \nsector. IBFR 2024 has sixteen essays contributed primarily \nby the faculty and alumni of NIBM in collaboration with'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe InDesign CC 2017 (Windows)', 'creationdate': '2024-11-13T13:26:09+05:30', 'moddate': '2024-12-02T14:37:36+05:30', 'trapped': '/False', 'source': 'text', 'total_pages': 248, 'page': 0, 'page_label': 'i'}, page_content='by the faculty and alumni of NIBM in collaboration with \noutside experts wherever required covering aspects like \nmacroeconomy and financial markets, risk management, \ninformation technology and issues in HR and strategy… \nAll the sixteen essays have not only maintained the high \nacademic standards already set by the previous reports \nbut also improved the quality and rigour of analysis. It is a \nwelcome and timely addition to the growing literature on \nthe subject.\nRavindra H. Dholakia Member of Central Board of RBI;            \nformer Member of Monetary Policy Committee, RBI and Professor, \nIIM Ahmedabad. \nI\nBFR 2024 is a valuable compendium of articles on topi-\ncal issues in banking and finance. Its focus on the latest \ndevelopments and challenges in financial markets, risk'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe InDesign CC 2017 (Windows)', 'creationdate': '2024-11-13T13:26:09+05:30', 'moddate': '2024-12-02T14:37:36+05:30', 'trapped': '/False', 'source': 'text', 'total_pages': 248, 'page': 0, 'page_label': 'i'}, page_content='developments and challenges in financial markets, risk \nmanagement, digitalization, HR and strategy is commen-\ndable. It will be of immense benefit to academicians, \npractitioners and policymakers, in India and abroad.  \nBhimaraya Metri Director, IIM Nagpur\nT\nhe 2024 edition of IBFR is indeed a real treasure in the \nrealms of BFSI Research, Policy and Practice. It’s loaded \nwith insightful, analytical and sometimes intriguing posers \nto readers on a diverse range of topical issues—macro-\neconomy to financial sector, including insurance space and \nthe new normal in risk management to digital disruption. \nLatest development, such as, application of ECL mechanism \nand ESG framework also find a place in eruditely scripted \nfeatures. Another redeeming feature of such a priceless'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe InDesign CC 2017 (Windows)', 'creationdate': '2024-11-13T13:26:09+05:30', 'moddate': '2024-12-02T14:37:36+05:30', 'trapped': '/False', 'source': 'text', 'total_pages': 248, 'page': 0, 'page_label': 'i'}, page_content='features. Another redeeming feature of such a priceless \npublication relates to finer nuances of governance, well \nmanifested in the papers on penal action by supervisors, \nlearning from global bank failure and deft analysis of \nsomewhat off-beat embedded finance options... All in all, \nIBFR is truly readers’ privilege and BFSI’s pride!\nAtanu Kumar Das Director, Institute of Insurance and            \nRisk Management (IIRM), Hyderabad; former Managing Director \nand CEO, Bank of India\nI \nam pleased to see that NIBM has come out with its Annual \nBanking and Finance Report 2024. The issue carries well \nresearched articles by the faculty... and the scholarship is \nquite evident. I am sure that the banking fraternity would \nimmensely benefit from these well-articulated research'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe InDesign CC 2017 (Windows)', 'creationdate': '2024-11-13T13:26:09+05:30', 'moddate': '2024-12-02T14:37:36+05:30', 'trapped': '/False', 'source': 'text', 'total_pages': 248, 'page': 0, 'page_label': 'i'}, page_content='immensely benefit from these well-articulated research \npapers. … I am particularly happy that the rich volume \ncarries applied research papers on the emerging and critical \nissues like ESG, Dynamics of ECL, and Emerging Regulatory \nIssues… I strongly recommend it to be read by practitioners, \npolicy makers and students.  \nJustin C. McCarthy Chief Executive Officer, PRMIA \n(Professional Risk Managers’ International Association)\nT\nhe India Banking and Financial Report 2024 covers a \nrange of issues—from macro economy to performance \nof the credit guarantee schemes for MSMEs, cross border \nliquidity, risk management and HR that are of current \ninterest in BFSI sector. Besides this, the Report also is rich \nwith information and data that are analysed and reviewed')]

# %% [markdown]
# ### Extract Tables from a PDF with pdfplumber

# %%
import pdfplumber
import pandas as pd

def extract_tables_from_pdf(pdf_path: str):
    all_tables = []
    
    with pdfplumber.open(pdf_path) as pdf:
        for page_num, page in enumerate(pdf.pages, start=1):
            tables = page.extract_tables()
            for table_num, table in enumerate(tables):
                if table:  # Skip empty tables
                    df = pd.DataFrame(table[1:], columns=table[0])
                    df["page"] = page_num
                    df["table_number"] = table_num + 1
                    all_tables.append(df)
    
    return all_tables  # List of DataFrames

# %%
extracted_tables = extract_tables_from_pdf('India Banking and Finance Report 2024.pdf')

# %%
# Display first table
if extracted_tables:
    print(extracted_tables[0].head())
else:
    print("No tables found.")
# Out:
# Empty DataFrame
# Columns: [m of articles on the Indian and global
# , across sixteen chapters: from latest
# talization of Trade and regulatory contours
# NIBM MEs. The discussion, in each chapter, is
# e the earlier editions, the style remains
# n integrated and volatile world of banking INDIA
# nd the key lessons for the future.
# BANKING
# d in the papers on penal action by supervisors,
# om global bank failure and deft analysis of
# off-beat embedded finance options... All in all,
# ly readers’ privilege and BFSI’s pride!
# umar Das Director, Institute of Insurance and
# AND
# ement (IIRM), Hyderabad; former Managing Director
# ank of India
# FINANCE
# ed to see that NIBM has come out with its Annual
# and Finance Report 2024. The issue carries well
# articles by the faculty... and the scholarship is
# ent. I am sure that the banking fraternity would
# y benefit from these well-articulated research
# REPORT
# I am particularly happy that the rich volume
# plied research papers on the emerging and critical
# ESG, Dynamics of ECL, and Emerging Regulatory
# strongly recommend it to be read by practitioners,
# ers and students.
# 2024
# . McCarthy Chief Executive Officer, PRMIA
# al Risk Managers’ International Association)
# ia Banking and Financial Report 2024 covers a
# of issues—from macro economy to performance
# it guarantee schemes for MSMEs, cross border
# isk management and HR that are of current
# BFSI sector. Besides this, the Report also is rich Edited
# mation and data that are analysed and reviewed
# yered expertise—the authors’ own insight, by
# expert reviews and a round table of another set of
# SANJAY ARINDAM PARTHA e suggestions made after such rigorous analysis
# Report a must-read for all the stakeholders in the
# ector—policymakers and practitioners as well as
# BASU
# RAY
# BANDYOPADHYAY ans and students.
# Killawala Author and Adviser, Strategic Communi-
# er Principal Adviser, Communication, RBI
# ISBN 978-93-327-0655-2
# N
# M
# INR 1495 (Ind sub)
# ation.org
# US$ 79.95 (overseas)
# INR 2595 (Ind sub)
# US$ 89.95 (overseas), c
# mi
# e
# d
# a
# c
# A
# y
# b
# d
# e
# h
# s
# bli
# u
# p
# s
# i
# 4
# 2
# 0
# 2
# R
# F
# B
# I, page, table_number]
# Index: []

# %% [markdown]
# ### Convert Extracted Tables to JSON Format

# %%
import json

def convert_tables_to_json(tables: list):
    json_tables = []

    for i, df in enumerate(tables):
        # Clean column names and remove NaNs
        df.columns = [str(col).strip() for col in df.columns]
        df = df.dropna(how='all').dropna(axis=1, how='all').fillna("")

        json_data = df.to_dict(orient="records")

        # Wrap with metadata
        json_tables.append({
            "table_id": f"table_{i+1}",
            "page": int(df.get("page", [None])[0]) if "page" in df else None,
            "data": json_data
        })

    return json_tables

# %%
# Convert extracted tables
json_formatted_tables = convert_tables_to_json(extracted_tables)
# Out:
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\3203751871.py:11: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   json_data = df.to_dict(orient="records")

# %% [markdown]
# ### Convert Table Rows Langchain Documents

# %%
from langchain.schema import Document

def table_to_documents(json_tables: list):
    docs = []
    for table in json_tables:
        # Convert table data (list of dicts) back to a DataFrame
        df = pd.DataFrame(table["data"])
        
        # Convert to markdown (GPT-friendly format)
        markdown = df.to_markdown(index=False)
        doc = Document(
            page_content=f"Table ID: {table['table_id']} (Page {table['page']})\n\n{markdown}",
            metadata={
                "source": "table",
                "table_id": table["table_id"],
                "page": table["page"]
            }
        )
        docs.append(doc)
    return docs

# %%
table_docs = table_to_documents(json_formatted_tables)
table_docs
# Out:
# [Document(metadata={'source': 'table', 'table_id': 'table_1', 'page': None}, page_content='Table ID: table_1 (Page None)\n\n'),
#  Document(metadata={'source': 'table', 'table_id': 'table_2', 'page': None}, page_content='Table ID: table_2 (Page None)\n\n'),
#  Document(metadata={'source': 'table', 'table_id': 'table_3', 'page': None}, page_content='Table ID: table_3 (Page None)\n\n'),
#  Document(metadata={'source': 'table', 'table_id': 'table_4', 'page': None}, page_content='Table ID: table_4 (Page None)\n\n'),
#  Document(metadata={'source': 'table', 'table_id': 'table_5', 'page': 28}, page_content='Table ID: table_5 (Page 28)\n\n| None   | O/N   | O/N     | O/N      | O/N   | Term     | Term   | Notice   | Term    | 3M   | 3M    | 3Ma i   | bl    | 12M   | 1Y    | 5Y    | 10Y   |   page |   table_number |\n|        | TRE   | Mkt     | Call     | MI-   | TREPS    | Mkt    | Money    | Money   | TB   | GOI   | v       | a     | CD    | GOI   | GOI   | GOI   |        |                |\n|        | PS    | Repo    |          | BOR   |          | Repo   |          |         |      |       | a       | l     |       |       |       |       |        |                |\n|        |       |         |          |       |          |        |          |         |      |       | CD      | 12M   |       |       |       |       |        |                |\n|        |       |         |          |       |          |        |          |         |      |       | s       | TB    |       |       |       |       |        |                |\n|        |       |         |          |       |          |        |          |         |      |       | i       |       |       |       |       |       |        |                |\n|:-------|:------|:--------|:---------|:------|:---------|:-------|:---------|:--------|:-----|:------|:--------|:------|:------|:------|:------|:------|-------:|---------------:|\n| O/N    | 1 00  |         |          |       |          |        |          |         |      | d     |         |       |       |       |       |       |     28 |              1 |\n| TREPS  |       |         |          |       |          |        |          |         |      | n     |         |       |       |       |       |       |        |                |\n|        |       |         |          |       |          |        |          |         |      | a     |         |       |       |       |       |       |        |                |\n|        |       |         |          |       |          |        |          |         |      | e     |         |       |       |       |       |       |        |                |\n|        |       |         |          |       |          |        |          |         |      | n     |         |       |       |       |       |       |        |                |\n|        |       |         |          |       |          |        |          |         |      | u     |         |       |       |       |       |       |        |                |\n| O/N    | 1 00  | 1 00    |          |       |          |        |          | h       | P    |       |         |       |       |       |       |       |     28 |              1 |\n| Mkt    |       |         |          |       |          |        |          | t       | M,   |       |         |       |       |       |       |       |        |                |\n| Repo   |       |         |          |       |          |        |          |         | B    |       |         |       |       |       |       |       |        |                |\n|        |       |         |          |       |          |        |          |         | NI   |       |         |       |       |       |       |       |        |                |\n| O/N    | 0 96  | 0 97    | 1 00     |       |          |        | a        | wi      |      |       |         |       |       |       |       |       |     28 |              1 |\n| Call   |       |         |          |       |          |        |          | n       |      |       |         |       |       |       |       |       |        |                |\n|        |       |         |          |       |          |        |          | o       |      |       |         |       |       |       |       |       |        |                |\n|        |       |         |          |       |          |        |          | ti      |      |       |         |       |       |       |       |       |        |                |\n| O/N    | 0 96  | 0 97    | 1 00     | 1 00  |          |        | ci       |  ...
#  Document(metadata={'source': 'table', 'table_id': 'table_6', 'page': 29}, page_content='Table ID: table_6 (Page 29)\n\n|    | 2019   | 2020   | 2021   | 2022     | 2023    |   page |   table_number |\n|:---|:-------|:-------|:-------|:---------|:--------|-------:|---------------:|\n| CA | 9 58%  | 9 47%  | 10 14% | 10 22%   | 10 08%  |     29 |              1 |\n| SA | 31 93% | 32 19% | 33 56% | 34 57%   | n33 05% |     29 |              1 |\n| TD | 58 50% | 58 34% | 56 30% | o        | 56 88%  |     29 |              1 |\n|    |        |        |        | z        |         |        |                |\n|    |        |        |        | 55 21m%a |         |        |                |'),
#  Document(metadata={'source': 'table', 'table_id': 'table_7', 'page': 29}, page_content='Table ID: table_7 (Page 29)\n\n|         | Mar 2022   | Mar 2023   | Mar 2024   |   page |   table_number |\n|:--------|:-----------|:-----------|:-----------|-------:|---------------:|\n| WACR    | 3 34%      | 6 61%      | 6 58%      |     29 |              2 |\n| CD Rate | 4 65%      | 7 43%      | 7 61%      |     29 |              2 |'),
#  Document(metadata={'source': 'table', 'table_id': 'table_8', 'page': 29}, page_content='Table ID: table_8 (Page 29)\n\n|           | c          | Mar-22   | Mar-23   | Mar-24   |   page |   table_number |\n|           | A          |          |          |          |        |                |\n|           | Mar-y2 1   |          |          |          |        |                |\n|           | b          |          |          |          |        |                |\n|:----------|:-----------|:---------|:---------|:---------|-------:|---------------:|\n| WALR      | d          | 8 74     | 9 72     | 9 83     |     29 |              3 |\n|           | h e9 1     |          |          |          |        |                |\n| Change bl | s          | -0 36    | 0 98     | 0 11     |     29 |              3 |\n| u         | i          |          |          |          |        |                |\n| p         | 5 28       | 5 03     | 6 16     | 6 88     |     29 |              3 |\n| WADTs DR  |            |          |          |          |        |                |\n| i         |            |          |          |          |        |                |\n| 4         |            | -0 25    | 1 13     | 0 72     |     29 |              3 |\n| 2         |            |          |          |          |        |                |\n| C0hange   |            |          |          |          |        |                |'),
#  Document(metadata={'source': 'table', 'table_id': 'table_9', 'page': 29}, page_content='Table ID: table_9 (Page 29)\n\n|        | Mar-21   | Mar-22   | Mar-23   | Mar-24   |   page |   table_number |\n|:-------|:---------|:---------|:---------|:---------|-------:|---------------:|\n| WALR   | 7 92     | 7 63     | 9 32     | 9 37     |     29 |              4 |\n| Change |          | -0 29    | 1 69     | 0 05     |     29 |              4 |\n| WADTDR | 3 85     | 4 12     | 6 48     | 6 62     |     29 |              4 |\n| Change |          | 0 27     | 2 36     | 0 14     |     29 |              4 |'),
#  Document(metadata={'source': 'table', 'table_id': 'table_10', 'page': 30}, page_content='Table ID: table_10 (Page 30)\n\n|            | 2021   | 2022   | 2023   | 2024   |   page |   table_number |\n|:-----------|:-------|:-------|:-------|:-------|-------:|---------------:|\n| CASA ratio | 41 79  | 42 50  | 40 63  | 40 44  |     30 |              1 |\n| NIM        | 2 42   | 2 42   | 2 72   | 3 25   |     30 |              1 |\n| CAR        | 14 19  | 14 47  | 15 71  | 16 16  |     30 |              1 |\n| ROA        | 0 26   | 0 52   | 0 72   | 1 03   |     30 |              1 |'),
#  Document(metadata={'source': 'table', 'table_id': 'table_11', 'page': 30}, page_content='Table ID: table_11 (Page 30)\n\n|            | 2021   | 2022   | 2023   | 2024   |   page |   table_number |\n|:-----------|:-------|:-------|:-------|:-------|-------:|---------------:|\n| CASA ratio | 48 04  | 49 07  | 46 07  | 40 68  |     30 |              2 |\n| NIM        | 3 70   | 3 70   | 4 04   | 4 31   |     30 |              2 |\n| CAR        | 19 33  | 19 54  | 18 98  | 17 90  |     30 |              2 |\n| ROA        | 1 37   | 1 70   | 1 86   | 2 24   |     30 |              2 |'),
#  Document(metadata={'source': 'table', 'table_id': 'table_12', 'page': 33}, page_content='Table ID: table_12 (Page 33)\n\n| 6.80   | %   |    | 3   | 3.99   |   page |   table_number |\n|:-------|:----|:---|:----|:-------|-------:|---------------:|\n|        |     |    |     |        |     33 |              1 |\n|        |     |    |     |        |     33 |              1 |\n| 7.23   | %   |    | 2   | 9.13   |     33 |              1 |\n| 3.02   | %   |    | 2   | 3.68   |     33 |              1 |\n|        |     |    |     |        |     33 |              1 |\n|        |     |    |     |        |     33 |              1 |'),
#  Document(metadata={'source': 'table', 'table_id': 'table_13', 'page': 33}, page_content='Table ID: table_13 (Page 33)\n\n|    | None   |   page |   table_number |\n|:---|:-------|-------:|---------------:|\n| 4  |        |     33 |              2 |\n|    |        |     33 |              2 |\n| 6  |        |     33 |              2 |\n|    |        |     33 |              2 |\n|    |        |     33 |              2 |\n|    |        |     33 |              2 |\n|    |        |     33 |              2 |\n|    |        |     33 |              2 |\n|    |        |     33 |              2 |\n|    |        |     33 |              2 |'),
#  Document(metadata={'source': 'table', 'table_id': 'table_14', 'page': 33}, page_content='Table ID: table_14 (Page 33)\n\n| None   |    |   page |   table_number |\n|:-------|:---|-------:|---------------:|\n|        |    |     33 |              3 |\n|        |    |     33 |              3 |\n|        |    |     33 |              3 |\n|        |    |     33 |              3 |\n|        |    |     33 |              3 |\n|        |    |     33 |              3 |\n|        |    |     33 |              3 |\n|        |    |     33 |              3 |'),
#  Document(metadata={'source': 'table', 'table_id': 'table_15', 'page': 34}, page_content='Table ID: table_15 (Page 34)\n\n| None   |      |   page |   table_number |\n|:-------|:-----|-------:|---------------:|\n|        | 23.1 |     34 |              1 |\n|        |      |     34 |              1 |\n|        |      |     34 |              1 |\n|        |      |     34 |              1 |\n|        |      |     34 |              1 |\n|        |      |     34 |              1 |'),
#  Document(metadata={'source': 'table', 'table_id': 'table_16', 'page': 34}, page_content='Table ID: table_16 (Page 34)\n\n| None   |    |   page |   table_number |\n|:-------|:---|-------:|---------------:|\n|        |    |     34 |              2 |\n|        |    |     34 |              2 |\n|        |    |     34 |              2 |'),
#  Document(metadata={'source': 'table', 'table_id': 'table_17', 'page': 35}, page_content='Table ID: table_17 (Page 35)\n\n| None   |    |   page |   table_number |\n|:-------|:---|-------:|---------------:|\n|        | 21 |     35 |              1 |\n| n      |    |     35 |              1 |\n|        |    |     35 |              1 |\n|        |    |     35 |              1 |\n|        |    |     35 |              1 |\n|        |    |     35 |              1 |\n|        |    |     35 |              1 |\n|        | n  |     35 |              1 |\n|        |    |     35 |              1 |'),
#  Document(metadata={'source': 'table', 'table_id': 'table_18', 'page': 36}, page_content='Table ID: table_18 (Page 36)\n\n| None   |    |   page |   table_number |\n|:-------|:---|-------:|---------------:|\n|        |    |     36 |              1 |\n|        |    |     36 |              1 |\n|        |    |     36 |              1 |\n|        |    |     36 |              1 |\n|        | 22 |     36 |              1 |\n|        |    |     36 |              1 |\n|        |    |     36 |              1 |\n|        |    |     36 |              1 |'),
#  Document(metadata={'source': 'table', 'table_id': 'table_19', 'page': 37}, page_content='Table ID: table_19 (Page 37)\n\n| 42%   |     | 40%   | 3   | 6%   | 34%   | 3%   | 46%   | 45%   | 2   |   page |   table_number |\n|:------|:----|:------|:----|:-----|:------|:-----|:------|:------|:----|-------:|---------------:|\n|       | 19% |       |     |      |       |      |       |       |     |     37 |              1 |\n| 14%   | 19% | 14%   | 1   | 7%   | 18%   | 5%   | 15%   | 16%   | 1   |     37 |              1 |'),
#  Document(metadata={'source': 'table', 'table_id': 'table_20', 'page': 38}, page_content='Table ID: table_20 (Page 38)\n\n| Resistance at 83.5                                                   | None   |   page |   table_number |\n| Support at 83                                                        |        |        |                |\n| ola(cid:6)lity: range has narrowed substan(cid:6)ally                |        |        |                |\n| o                                                                    |        |        |                |\n| r                                                                    |        |        |                |\n| f                                                                    |        |        |                |\n| e                                                                    |        |        |                |\n| s                                                                    |        |        |                |\n| a                                                                    |        |        |                |\n| h                                                                    |        |        |                |\n| c                                                                    |        |        |                |\n| r                                                                    |        |        |                |\n| u                                                                    |        |        |                |\n| p                                                                    |        |        |                |\n| r                                                                    |        |        |                |\n| o                                                                    |        |        |                |\n| f                                                                    |        |        |                |\n|:---------------------------------------------------------------------|:-------|-------:|---------------:|\n|                                                                      | Auto   |     38 |              1 |\n| e                                                                    |        |     38 |              1 |\n| bl                                                                   |        |        |                |\n| a                                                                    |        |        |                |\n| ail                                                                  |        |        |                |\n| Average True Range shows volaitlity has fallen substan(cid:10)ally v |        |        |                |\n| a                                                                    |        |        |                |\n| s                                                                    |        |        |                |\n| i                                                                    |        |        |                |\n| d                                                                    |        |        |                |\n| n                                                                    |        |        |                |\n| a                                                                    |        |        |                |\n| e                                                                    |        |        |                |\n| n                                                                    |        |        |                |'),
#  Document(metadata={'source': 'table', 'table_id': 'table_21', 'page': 40}, page_content='Table ID: table_21 (Page 40)\n\n| None   |   page |   table_number |\n|:-------|-------:|---------------:|\n|        |     40 |              1 |\n|        |     40 |              1 |'),
#  Document(metadata={'source': 'table', 'table_id': 'table_22', 'page': 40}, page_content='Table ID: table_22 (Page 40)\n\n| None   |   page |   table_number |\n|:-------|-------:|---------------:|\n|        |     40 |              2 |\n|        |     40 |              2 |'),
#  Document(metadata={'source': 'table', 'table_id': 'table_23', 'page': 40}, page_content='Table ID: table_23 (Page 40)\n\n| None   |   page |   table_number |\n|:-------|-------:|---------------:|\n|        |     40 |              3 |'),
#  Document(metadata={'source': 'table', 'table_id': 'table_24', 'page': 40}, page_content='Table ID: table_24 (Page 40)\n\n| None   |   page |   table_number |\n|:-------|-------:|---------------:|\n|        |     40 |              4 |'),
#  Document(metadata={'source': 'table', 'table_id': 'table_25', 'page': 40}, page_content='Table ID: table_25 (Page 40)\n\n| None   |   page |   table_number |\n|:-------|-------:|---------------:|\n| r      |     40 |              5 |\n| f      |        |                |'),
#  Document(metadata={'source': 'table', 'table_id': 'table_26', 'page': 40}, page_content='Table ID: table_26 (Page 40)\n\n| None   |   page |   table_number |\n|:-------|-------:|---------------:|\n|        |     40 |              6 |'),
#  Document(metadata={'source': 'table', 'table_id': 'table_27', 'page': 40}, page_content='Table ID: table_27 (Page 40)\n\n| None   |   page |   table_number |\n|:-------|-------:|---------------:|\n|        |     40 |              7 |'),
#  Document(metadata={'source': 'table', 'table_id': 'table_28', 'page': 44}, page_content='Table ID: table_28 (Page 44)\n\n| None   |    |   page |   table_number |\n|:-------|:---|-------:|---------------:|\n|        |    |     44 |              1 |\n|        |    |     44 |              1 |\n|        |    |     44 |              1 |\n|        |    |     44 |              1 |'),
#  Document(metadata={'source': 'table', 'table_id': 'table_29', 'page': 44}, page_content='Table ID: table_29 (Page 44)\n\n|    | None   |   page |   table_number |\n|:---|:-------|-------:|---------------:|\n|    |        |     44 |              2 |\n|    |        |     44 |              2 |\n|    |        |     44 |              2 |'),
#  Document(metadata={'source': 'table', 'table_id': 'table_30', 'page': 44}, page_content='Table ID: table_30 (Page 44)\n\n|    |   page |   table_number |\n|:---|-------:|---------------:|\n|    |     44 |              3 |'),
#  Document(metadata={'source': 'table', 'table_id': 'table_31', 'page': 44}, page_content='Table ID: table_31 (Page 44)\n\n| None   |   page |   table_number |\n|:-------|-------:|---------------:|\n|        |     44 |              4 |'),
#  Document(metadata={'source': 'table', 'table_id': 'table_32', 'page': 44}, page_content='Table ID: table_32 (Page 44)\n\n| None   |   page |   table_number |\n|:-------|-------:|---------------:|\n|        |     44 |              5 |'),
#  Document(metadata={'source': 'table', 'table_id': 'table_33', 'page': None}, page_content='Table ID: table_33 (Page None)\n\n'),
#  Document(metadata={'source': 'table', 'table_id': 'table_34', 'page': 47}, page_content='Table ID: table_34 (Page 47)\n\n| Year                                      | GDP (At Cur-   | Gross Fiscal     | Financing of GFD -   | GFD to   | GoI Market Bor-   |   page |   table_number |\n|                                           | rent Prices)   | Deficit of GoI   | Market Borrowings    | GDP      | rowing to GFD     |        |                |\n|                                           | ($ in Cr )     | ($ in Cr )       | ($ in Cr )           | (%)      | (%)               |        |                |\n|:------------------------------------------|:---------------|:-----------------|:---------------------|:---------|:------------------|-------:|---------------:|\n| Market Borrowings of Government of India  |                |                  |                      |          |                   |     47 |              1 |\n| 2023-24                                   | NA             | 1786816          | 1180911              | -        | 66 09             |     47 |              1 |\n| 2022-23                                   | 27240712       | 1755319          | 1108183              | 6 44     | 63 13             |     47 |              1 |\n| 2021-22                                   | 23471012       | 1584521          | 704097               | 6 75     | 44 n44            |     47 |              1 |\n|                                           |                |                  |                      |          | o                 |        |                |\n| 2020-21                                   | 19829927       | 1818291          | 1032907              | 9 17     | z                 |     47 |              1 |\n|                                           |                |                  |                      |          | a                 |        |                |\n|                                           |                |                  |                      |          | m 56 81           |        |                |\n| 2019-20                                   | 20103593       | 933651           | 473968               | 4 64     | A                 |     47 |              1 |\n|                                           |                |                  |                      |          | m 50 76           |        |                |\n| o                                         |                |                  |                      |          |                   |     47 |              1 |\n| r                                         |                |                  |                      |          |                   |        |                |\n| Market Borrowings of State Government e f |                |                  |                      |          |                   |        |                |\n| 2023-24                                   | NA             | NA               | NA                   | s        | -                 |     47 |              1 |\n|                                           |                |                  |                      | a        |                   |        |                |\n|                                           |                |                  |                      | -h       |                   |        |                |\n|                                           |                |                  |                      | c        |                   |        |                |\n| 2022-23                                   | 27240712       | 882811           | 689788               | r        | 78 14             |     47 |              1 |\n|                                           |                |                  |                      | u        |                   |        |                |\n|                                           |                |                  |                      | p3 24    |               ...
#  Document(metadata={'source': 'table', 'table_id': 'table_35', 'page': 48}, page_content='Table ID: table_35 (Page 48)\n\n| Quarter   | TREPS   | Repo   | CALL   | LAF Window ($ in Cr )   | None           |   page |   table_number |\n|           | (%)     | (%)    | (%)    |                         |                |        |                |\n|:----------|:--------|:-------|:-------|:------------------------|:---------------|-------:|---------------:|\n|           |         |        |        | Repo + MSF              | REV Repo / SDF |     48 |              1 |\n| 2021-22Q4 | 75 8    | 22 6   | 1 6    | 2984                    | 160453         |     48 |              1 |\n| 2022-23Q1 | 74 1    | 23 8   | 2 1    | 397                     | 205135         |     48 |              1 |\n| 2022-23Q2 | 72      | 25 6   | 2 4    | 7686                    | 115628         |     48 |              1 |\n| 2022-23Q3 | 72 5    | 25 5   | 2      | 6011                    | 105974         |     48 |              1 |\n| 2022-23Q4 | 68 6    | 28 9   | 2 5    | 3983                    | 111681 m       |     48 |              1 |\n| 2023-24Q1 | 61 1    | 36 7   | 2 2    | 10322                   | A              |     48 |              1 |\n|           |         |        |        |                         | 104790 m       |        |                |\n|           |         |        |        |                         | o              |        |                |\n| 2023-24Q2 | 67 1    | 30 8   | 2 1    | 33304                   | r              |     48 |              1 |\n|           |         |        |        |                         | f              |        |                |\n|           |         |        |        |                         | 83262e         |        |                |\n|           |         |        |        |                         | s              |        |                |\n| 2023-24Q3 | 69      | 28 8   | 2 2    | 94786                   | a              |     48 |              1 |\n|           |         |        |        |                         | h              |        |                |\n|           |         |        |        |                         | 4r c6289       |        |                |\n|           |         |        |        |                         | u              |        |                |\n| 2023-24Q4 | 66 9    | 30 9   | 2 2    | 29062                   | p              |     48 |              1 |\n|           |         |        |        |                         | r 65366        |        |                |\n|           |         |        |        |                         | o              |        |                |\n|           |         |        |        |                         | f              |        |                |'),
#  Document(metadata={'source': 'table', 'table_id': 'table_36', 'page': 49}, page_content='Table ID: table_36 (Page 49)\n\n|         | Issuance Summary of Government Securities in India   | None      |   page |   table_number |\n|:--------|:-----------------------------------------------------|:----------|-------:|---------------:|\n| Period  | Issuance of Central Government Securities            |           |     49 |              1 |\n|         | Uniform                                              | Average   |     49 |              1 |\n|         | Price                                                | Weekly    |        |                |\n|         | (Nos)                                                | Issuance  |        |                |\n|         |                                                      | (INR Cr ) |        |                |\n| FY20    | 0                                                    | 12000     |     49 |              1 |\n| FY21    | 0                                                    | n         |     49 |              1 |\n|         |                                                      | o         |        |                |\n|         |                                                      | a z 15400 |        |                |\n| FY22    | 0                                                    | m         |     49 |              1 |\n|         |                                                      | 12928     |        |                |\n| FY23    | 127                                                  | 14302     |     49 |              1 |\n| Q1-FY24 | 29                                                   | 12900     |     49 |              1 |\n| Q2-FY24 | 30                                                   | 14640     |     49 |              1 |\n| Q3-FY24 | 40                                                   | 18922     |     49 |              1 |\n| Q4-FY24 | 14                                                   | 28789     |     49 |              1 |'),
#  Document(metadata={'source': 'table', 'table_id': 'table_37', 'page': 49}, page_content='Table ID: table_37 (Page 49)\n\n| None   |    |   page |   table_number |\n|:-------|:---|-------:|---------------:|\n|        |    |     49 |              2 |\n|        |    |     49 |              2 |\n|        |    |     49 |              2 |\n|        |    |     49 |              2 |\n|        |    |     49 |              2 |\n|        |    |     49 |              2 |\n|        |    |     49 |              2 |\n|        |    |     49 |              2 |'),
#  Document(metadata={'source': 'table', 'table_id': 'table_38', 'page': 50}, page_content='Table ID: table_38 (Page 50)\n\n| o                                                             | None   |   page |   table_number |\n| F                                                             |        |        |                |\n| Outstanding Mc arket for Municipal and Green Bonds in India   |        |        |                |\n| i                                                             |        |        |                |\n|:--------------------------------------------------------------|:-------|-------:|---------------:|\n| Year                                                          |        |     50 |              1 |\n|                                                               | Green  |     50 |              1 |\n|                                                               | Bond   |        |                |\n| 2017                                                          | 7 59   |     50 |              1 |\n| 2018                                                          | 8 74   |     50 |              1 |\n| 2019                                                          | 8 49   |     50 |              1 |\n| 2020                                                          |        |     50 |              1 |\n| 2021 I                                                        | 6 72   |     50 |              1 |\n| 2022                                                          | 6 93   |     50 |              1 |\n| 2023                                                          | 8 14   |     50 |              1 |\n| 2024 #                                                        | 7 90   |     50 |              1 |\n| Total                                                         | 7 79   |     50 |              1 |\n|                                                               |        |     50 |              1 |'),
#  Document(metadata={'source': 'table', 'table_id': 'table_39', 'page': 51}, page_content='Table ID: table_39 (Page 51)\n\n| at                                              | None     |   page |   table_number |\n| Outstandicnig Basel III / AT-1 Bonds in India   |          |        |                |\n| o                                               |          |        |                |\n|:------------------------------------------------|:---------|-------:|---------------:|\n| Scheduled Commercial Banks                      | Credit   |     51 |              1 |\n| a                                               | Rating   |        |                |\n| d                                               | AA+      |     51 |              1 |\n| Bank of Baroda u n                              |          |        |                |\n| o                                               | AA       |     51 |              1 |\n| F                                               |          |        |                |\n| Bank of India c                                 |          |        |                |\n| mi                                              | AA       |     51 |              1 |\n| Bank of Maharashtra e                           |          |        |                |\n| d                                               |          |        |                |\n| a                                               | AA+      |     51 |              1 |\n| Canara Bank A c                                 |          |        |                |\n| y                                               | AA+      |     51 |              1 |\n| Central Bank o f Ibndia                         |          |        |                |\n| d                                               |          |        |                |\n| e                                               | AA+      |     51 |              1 |\n| h                                               |          |        |                |\n| HDFC Banks Limited                              |          |        |                |\n| i                                               |          |        |                |\n| bl                                              | AA+      |     51 |              1 |\n| HDFC Fiurst Bank Ltd                            |          |        |                |\n| p                                               |          |        |                |\n| s                                               | AA+      |     51 |              1 |\n| Ind i ain Bank                                  |          |        |                |\n| 4                                               |          |        |                |\n| 2                                               | AA+      |     51 |              1 |\n| 2J0&K Grameen Bank                              |          |        |                |\n| Punjab National Bank                            | AA+      |     51 |              1 |\n| State Bank of India                             | AA+      |     51 |              1 |\n| The J&K Bank Limited                            | A        |     51 |              1 |\n| The South Indian Bank Ltd                       | A        |     51 |              1 |\n| Union Bank of India                             | AA+, AA  |     51 |              1 |\n| Yes Bank Limited                                | NA, D    |     51 |              1 |\n| Total Outstanding AT-1 Bonds                    | AA+ / AA |     51 |              1 |\n|                                                 | / A      |        |                |'),
#  Document(metadata={'source': 'table', 'table_id': 'table_40', 'page': 52}, page_content='Table ID: table_40 (Page 52)\n\n| 19   |    | 16   | 13   | 12   | 14   | 12   |   page |   table_number |\n|      |    |      |      | 5    |      | 3    |        |                |\n|:-----|:---|:-----|:-----|:-----|:-----|:-----|-------:|---------------:|\n| 9    |    | 5    | 8    |      | 5    |      |     52 |              1 |\n|      |    |      |      |      |      |      |     52 |              1 |\n|      |    |      |      |      |      |      |     52 |              1 |\n|      |    |      |      | 83   |      | 85   |     52 |              1 |\n| 72   |    | 79   | 80   |      | 81   |      |     52 |              1 |\n|      |    |      |      |      |      |      |     52 |              1 |'),
#  Document(metadata={'source': 'table', 'table_id': 'table_41', 'page': 53}, page_content='Table ID: table_41 (Page 53)\n\n|    | 1   | 7   | %1   | 5   | 6   | 4   |   page |   table_number |\n|:---|:----|:----|:-----|:----|:----|:----|-------:|---------------:|\n| 0  | %   |     |      |     |     |     |     53 |              1 |\n| 5  | 1   | 6   | %    | 3   | %   | 5   |     53 |              1 |\n|    | %   |     | 1    |     |     |     |        |                |\n|    |     |     |      |     |     |     |     53 |              1 |\n|    |     |     |      |     |     |     |     53 |              1 |\n|    |     |     |      |     |     |     |     53 |              1 |\n| 5  | %6  | 7   | %6   | 1   | 6   | 0   |     53 |              1 |\n|    |     |     |      |     |     |     |     53 |              1 |\n|    |     |     |      |     |     |     |     53 |              1 |\n|    |     |     |      |     |     |     |     53 |              1 |'),
#  Document(metadata={'source': 'table', 'table_id': 'table_42', 'page': 54}, page_content='Table ID: table_42 (Page 54)\n\n| 8%   | % 2   | 3   | 1   | 0   | % 1   | %   | 1   | 7   | 1   | 1   | 2   | % 2   | %   | 6%   | 7%   | % 1   | 7%   | 0   |   page |   table_number |\n| 4    | %     |     | %   | 8   | % 1   | 2   | %   |     | %   | 9   |     |       | 2   | 1    | 1    |       | 9    |     |        |                |\n| 1    |       |     | 1   |     |       | %   | 2   |     | 1   |     |     |       |     |      |      |       |      |     |        |                |\n|      |       |     |     |     |       |     |     |     | %   |     |     |       |     |      |      |       |      |     |        |                |\n|:-----|:------|:----|:----|:----|:------|:----|:----|:----|:----|:----|:----|:------|:----|:-----|:-----|:------|:-----|:----|-------:|---------------:|\n|      |       |     |     |     |       |     |     |     |     |     |     |       |     |      |      |       |      |     |     54 |              1 |\n|      |       | 9   |     | 6%  |       | 1   | %   | 3   |     | 6%  | 7   | % 3   | %   | 4    | 0    | % 2   | 5    | 7   |     54 |              1 |\n|      |       | 6%  |     |     |       |     |     |     |     |     |     |       | 2   |      |      |       |      |     |        |                |\n|      |       |     |     |     |       |     |     |     |     |     |     |       |     |      |      |       |      |     |     54 |              1 |\n| 6    | % 6   |     | % 6 | 6   | % 6   | %   |     |     | 6   | 5   |     |       |     |      |      |       |      |     |     54 |              1 |\n|      |       | 1   |     |     |       | 6   | 5   |     | %   |     |     |       | %   | 0    | 2    | % 4   | 9    | 9   |     54 |              1 |\n|      |       |     |     |     |       |     | %   |     |     |     |     |       |     |      |      |       |      |     |        |                |\n|      |       |     |     |     |       |     |     | 8   |     |     | 7   | % 3   | 4   |      |      |       |      |     |     54 |              1 |\n|      |       |     |     |     |       |     |     |     |     |     |     |       |     |      |      |       |      |     |     54 |              1 |'),
#  Document(metadata={'source': 'table', 'table_id': 'table_43', 'page': 55}, page_content='Table ID: table_43 (Page 55)\n\n| Summary       | GOI                         | US 3M   | UK   | u       | US    | UK    | GOI   |   page |   table_number |\n| Statistics    | 3M                          |         | 6M   | o       | 10Y   | 10Y   | 10Y   |        |                |\n|               |                             |         |      | GOFI    |       |       |       |        |                |\n|               |                             |         |      | c       |       |       |       |        |                |\n|               |                             |         |      | mi10Y   |       |       |       |        |                |\n|:--------------|:----------------------------|:--------|:-----|:--------|:------|:------|:------|-------:|---------------:|\n|               | Year: 2022; Total Obs = 225 |         |      |         |       |       |       |     55 |              1 |\n| Mean          | 5 23                        | 2 10    | 1 71 | 6 76    | 2 95  | 2 42  | 7 18  |     55 |              1 |\n| Maximum       | 6 57                        | 4 46    | 3 72 | 7 66    | 4 24  | 4 54  | 7 66  |     55 |              1 |\n| Std Deviation | 0 98                        | 1 53    | 0 99 | 0 53    | 0 71  | 0 91  | 0 28  |     55 |              1 |\n| Range         | 2 93                        | 4 38    | 3 72 | 1 83    | 2 58  | 3 45  | 1 09  |     55 |              1 |\n|               | Year: 2023; Total Obs = 230 |         |      |         |       |       |       |     55 |              1 |\n| Mean          | 6 74                        | 5 28    | 4 46 | 6 27    | 3 97  | 4 00  | 7 21  |     55 |              1 |\n| Maximum       | 7.06                        | 5.63    | 5.12 | 7 10    | 4.98  | 4.67  | 7.45  |     55 |              1 |\n| Std Deviation | 0 13                        | 0 33    | 0 61 | 0 41    | 0 42  | 0 41  | 0 12  |     55 |              1 |\n| Range         | 0 80                        | 1 11    | 2 27 | 1 27    | 1 68  | 1 56  | 0 49  |     55 |              1 |\n|               | Year: 2024; Total Obs = 75  |         |      |         |       |       |       |     55 |              1 |\n| Mean          | 6 88                        | 5 45    | 4 79 | 6 26    | 4 25  | 4 02  | 7 12  |     55 |              1 |\n| Maximum       | 7 02                        | 5 49    | 4 99 | 6.52    | 4 70  | 4 32  | 7 24  |     55 |              1 |\n| Std Deviation | 0 07                        | 0 02    | 0 13 | 0 12    | 0 21  | 0 14  | 0 05  |     55 |              1 |\n| Range         | 0 28                        | 0 08    | 0 44 | 0 58    | 0 83  | 0 64  | 0 22  |     55 |              1 |'),
#  Document(metadata={'source': 'table', 'table_id': 'table_44', 'page': 56}, page_content='Table ID: table_44 (Page 56)\n\n| None   |    |   page |   table_number |\n|:-------|:---|-------:|---------------:|\n|        |    |     56 |              1 |\n|        |    |     56 |              1 |\n|        |    |     56 |              1 |\n|        |    |     56 |              1 |\n|        |    |     56 |              1 |\n|        |    |     56 |              1 |\n|        |    |     56 |              1 |\n|        |    |     56 |              1 |\n|        |    |     56 |              1 |'),
#  Document(metadata={'source': 'table', 'table_id': 'table_45', 'page': 57}, page_content='Table ID: table_45 (Page 57)\n\n| None   |    |   page |   table_number |\n|:-------|:---|-------:|---------------:|\n|        |    |     57 |              1 |\n|        |    |     57 |              1 |\n|        |    |     57 |              1 |\n|        |    |     57 |              1 |\n|        |    |     57 |              1 |\n|        |    |     57 |              1 |\n|        |    |     57 |              1 |\n|        |    |     57 |              1 |\n|        |    |     57 |              1 |\n|        |    |     57 |              1 |'),
#  Document(metadata={'source': 'table', 'table_id': 'table_46', 'page': 58}, page_content='Table ID: table_46 (Page 58)\n\n| Debt Utilization Status by FPIs in India under various Routes as on June 06, 2024:   | None        |   page |   table_number |\n|:-------------------------------------------------------------------------------------|:------------|-------:|---------------:|\n| General Limit:                                                                       |             |     58 |              1 |\n| Instrument Type                                                                      | % of Limits |     58 |              1 |\n|                                                                                      | Utilised    |        |                |\n| Central Government Securities                                                        | 24 61%      |     58 |              1 |\n| Central Government Securities                                                        | 4 33%       |     58 |              1 |\n| State Government Securities                                                          | 3 19%       |     58 |              1 |\n| State Government Securities                                                          | m           |     58 |              1 |\n|                                                                                      | 0 00%       |        |                |\n|                                                                                      | A           |        |                |\n| Corporate Bonds                                                                      | m           |     58 |              1 |\n|                                                                                      | 15 81o%     |        |                |\n| r                                                                                    |             |     58 |              1 |\n| f                                                                                    |             |        |                |\n| Limit for Debt Investment in Voluntary Retention Route (VRR): s e                    |             |        |                |\n| Total Investment under VRR                                                           | a           |     58 |              1 |\n|                                                                                      | h           |        |                |\n|                                                                                      | c 72 37%    |        |                |\n|                                                                                      | r           |        |                |\n| u                                                                                    |             |     58 |              1 |\n| p                                                                                    |             |        |                |\n| Limit for Debt Investment in Fully Accessible Route (FAR):                           |             |        |                |\n| r                                                                                    |             |        |                |\n|                                                                                      | % Holding   |     58 |              1 |\n| Total Investment under FAR                                                           | 4 38%       |     58 |              1 |'),
# ...
#  Document(metadata={'source': 'table', 'table_id': 'table_182', 'page': 230}, page_content='Table ID: table_182 (Page 230)\n\n| Dependent Variable=CRARit   |         |   page |   table_number |\n|:----------------------------|:--------|-------:|---------------:|\n| Independent Factors         | P>|t|   |    230 |              1 |\n| LBUSINESS                   | 0 074*  |    230 |              1 |\n| CUST_COMPL_BR               | 0 00*** |    230 |              1 |\n| OWNGRPD1-OldPvt             | 0 011** |    230 |              1 |\n| OWNGRPD2-NewPvt             | ---     |    230 |              1 |\n| OWNGRPD3-PSB                | 0 00*** |    230 |              1 |\n| YRD1-2018                   | 0 087*  |    230 |              1 |\n| YRD2-2019                   | 0 911   |    230 |              1 |\n| YRD3-2020                   | 0 017** |    230 |              1 |\n| YRD4-2021                   | 0 582   |    230 |              1 |\n| YRD5-2022                   | ---     |    230 |              1 |\n| YRD6-2023                   | 0 689   |    230 |              1 |\n| a                           | 0 00*** |    230 |              1 |\n| v                           |         |        |                |\n| Intercept a                 |         |        |                |\n| s                           |         |    230 |              1 |\n| i                           |         |        |                |\n| Number of Observationds     |         |        |                |\n| n                           |         |        |                |\n| a                           |         |    230 |              1 |\n| F (k, df) e                 |         |        |                |\n| n                           |         |        |                |\n| u                           |         |    230 |              1 |\n| Prob>F P                    |         |        |                |\n| ,                           |         |        |                |\n| M                           |         |    230 |              1 |\n| R-squared B                 |         |        |                |\n| I                           |         |        |                |'),
#  Document(metadata={'source': 'table', 'table_id': 'table_183', 'page': 235}, page_content='Table ID: table_183 (Page 235)\n\n| PMS                                                   | CFS                                                |   page |   table_number |\n|:------------------------------------------------------|:---------------------------------------------------|-------:|---------------:|\n| Performance assessment is conducted as an year-end    | Performance is assessed on a continuous, real time |    235 |              1 |\n| activity                                              | basis                                              |        |                |\n| Backward-looking in nature                            | Forward-looking and considers future competency    |    235 |              1 |\n|                                                       | requirements                                       |        |                |\n| Feedback communication is one-way                     | It is a partnership dialogue to develop people     |    235 |              1 |\n| Does not lead to employee engagement                  | Employee engagement is the core of feedback        |    235 |              1 |\n| Breeds distrust and cynicism towards the organization | Develops a sense of belongingness towards the      |    235 |              1 |\n|                                                       | organization                                       |        |                |'),
#  Document(metadata={'source': 'table', 'table_id': 'table_184', 'page': 239}, page_content="Table ID: table_184 (Page 239)\n\n| G                   | None      | TABLE 16.2                              |   page |   table_number |\n|                     |           | roup Statistics on Performance Scores   |        |                |\n|:--------------------|:----------|:----------------------------------------|-------:|---------------:|\n|                     |           | Group Statistics                        |    239 |              1 |\n|                     | Std Error | Group                                   |    239 |              1 |\n|                     | Mean      |                                         |        |                |\n| Performance         | 27372     | Group1                                  |    239 |              1 |\n|                     | 20625     | Group2                                  |    239 |              1 |\n| Source: Authors' es |           | timation                                |    239 |              1 |"),
#  Document(metadata={'source': 'table', 'table_id': 'table_185', 'page': 240}, page_content='Table ID: table_185 (Page 240)\n\n| snaeM        | lavretnI         | reppU   | 40201       | 54401     |   page |   table_number |\n| fo           | ecnereffiD       |         | 3           | 3         |        |                |\n| ytilauqE     | ecnedfinoC       |         |             |           |        |                |\n| rof          | eht              |         |             |           |        |                |\n| tset-t       | fo               |         |             |           |        |                |\n| o            | %59              |         |             |           |        |                |\n| i            |                  |         |             |           |        |                |\n|:-------------|:-----------------|:--------|:------------|:----------|-------:|---------------:|\n|              |                  | rewoL   | 69796       | 55596     |    240 |              1 |\n|              |                  |         | 1           | 1         |        |                |\n|              | rorrE ecnereffiD |         | 27243       | 27243     |    240 |              1 |\n|              | dtS              |         | 0           | 0         |        |                |\n|              | ecnereffiD       |         | 4           | 4         |    240 |              1 |\n|              | naeM             |         | 2           | 2         |        |                |\n|              | )deliat-2(       |         | 0           | 0         |    240 |              1 |\n|              | giS              |         |             |           |        |                |\n|              | fd               |         | 82          | M         |    240 |              1 |\n|              |                  |         | wit         | B 220     |        |                |\n|              |                  |         | n           | NI        |        |                |\n|              |                  |         |             | h 62      |        |                |\n|              | a                |         | o           | 300       |    240 |              1 |\n|              | ci               |         | ti          | 7         |        |                |\n|              | o                |         | 300         |           |        |                |\n|              | s                |         | 7           |           |        |                |\n|              | s a t            |         |             |           |        |                |\n|              | n                |         |             |           |        |                |\n|              | i                |         |             |           |        |                |\n|              | n                |         |             |           |        |                |\n| at           | giS              |         | 683         |           |    240 |              1 |\n| d n ytilauqE |                  |         | 0           |           |        |                |\n| u            |                  |         |             |           |        |                |\n| secnairaV    |                  |         |             |           |        |                |\n| rof          |                  |         |             |           |        |                |\n| tseT         |                  |         |             |           |        |                |\n| s’eneveL fo  |                  |         |             |           |        |                |\n|              | F                |         | 477         |           |    240 |              1 |\n|              |                  |         | 0           |           |        |                |\n|              |                  |         | secnairav   | ton       |    240 |              1 |\n|              |                  |         | demussa     | secnairav |        |                |\n|             ...
#  Document(metadata={'source': 'table', 'table_id': 'table_186', 'page': 241}, page_content='Table ID: table_186 (Page 241)\n\n| High Perceived   | High Perceived                |   page |   table_number |\n| Organizational   | Organizational Support &      |        |                |\n| Support & No     | Continuous Feedback Group     |        |                |\n| Continuous       | n                             |        |                |\n| Feedback Group   |                               |        |                |\n|:-----------------|:------------------------------|-------:|---------------:|\n| Low Perceived    | o                             |    241 |              1 |\n| Organizational   | z                             |        |                |\n| Support & No     | Low Perceived Orgaanizational |        |                |\n| Continuous       | m                             |        |                |\n| Feedback Group   | Support & ContAinuous         |        |                |\n|                  | m                             |        |                |\n|                  | Feedback Grooup               |        |                |\n|                  | r                             |        |                |\n|                  | f                             |        |                |\n|                  | e                             |        |                |\n|                  | s                             |        |                |\n|                  | a                             |        |                |\n|                  | h                             |        |                |'),
#  Document(metadata={'source': 'table', 'table_id': 'table_187', 'page': 242}, page_content='Table ID: table_187 (Page 242)\n\n| M,                                                      | None   |   page |   table_number |\n| Dependent Variable: Perceived organizationBal support   |        |        |                |\n|:--------------------------------------------------------|:-------|-------:|---------------:|\n| Group1                                                  | N      |    242 |              1 |\n| Continuous feedback                                     | 12     |    242 |              1 |\n|                                                         | 12     |    242 |              1 |\n|                                                         | 24     |    242 |              1 |\n| No continuous feedback                                  | 12     |    242 |              1 |\n|                                                         | 12     |    242 |              1 |\n|                                                         | 24     |    242 |              1 |\n| Total                                                   | 24     |    242 |              1 |\n| s                                                       |        |        |                |\n| bli                                                     |        |        |                |\n| u                                                       |        |        |                |\n| p                                                       |        |        |                |\n| s                                                       |        |        |                |\n| i                                                       |        |        |                |\n| 4                                                       |        |        |                |\n| 2                                                       |        |        |                |\n|                                                         | 24     |    242 |              1 |\n|                                                         | 48     |    242 |              1 |'),
#  Document(metadata={'source': 'table', 'table_id': 'table_188', 'page': 242}, page_content='Table ID: table_188 (Page 242)\n\n| Dependent Variable: High Perceived Support   | None        |   page |   table_number |\n|:---------------------------------------------|:------------|-------:|---------------:|\n| Source                                       | Partial Eta |    242 |              2 |\n|                                              | Squared     |        |                |\n| Group1                                       | 656         |    242 |              2 |\n| Group2                                       | 427         |    242 |              2 |\n| Group1 *                                     | 000         |    242 |              2 |\n| Group2                                       |             |        |                |'),
#  Document(metadata={'source': 'table', 'table_id': 'table_189', 'page': 243}, page_content='Table ID: table_189 (Page 243)\n\n|    |   page |   table_number |\n|:---|-------:|---------------:|\n|    |    243 |              1 |\n|    |    243 |              1 |'),
#  Document(metadata={'source': 'table', 'table_id': 'table_190', 'page': 248}, page_content='Table ID: table_190 (Page 248)\n\n| None                  |   page |   table_number |\n|:----------------------|-------:|---------------:|\n| NIBM                  |    248 |              1 |\n| INDIA                 |        |                |\n| BANKING               |        |                |\n| AND                   |        |                |\n| FINANCE               |        |                |\n| REPORT                |        |                |\n| 2024                  |        |                |\n| Edited                |        |                |\n| by                    |        |                |\n| SANJAY ARINDAM PARTHA |        |                |\n| BASU                  |        |                |\n| RAY                   |        |                |\n| BANDYOPADHYAY         |        |                |\n|                       |    248 |              1 |\n|                       |    248 |              1 |\n|                       |    248 |              1 |'),
#  Document(metadata={'source': 'table', 'table_id': 'table_191', 'page': None}, page_content='Table ID: table_191 (Page None)\n\n')]

# %% [markdown]
# ### Merge text chunks document with table documents

# %%
all_docs = text_docs + table_docs  # combine both text and table docs
all_docs[:5]
# Out:
# [Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe InDesign CC 2017 (Windows)', 'creationdate': '2024-11-13T13:26:09+05:30', 'moddate': '2024-12-02T14:37:36+05:30', 'trapped': '/False', 'source': 'text', 'total_pages': 248, 'page': 0, 'page_label': 'i'}, page_content='IBFR 2024 is published by Academic Foundation in association with NIBM, Pune and is available for purchase from Amazon\nNATIONAL INSTITUTE OF \nBANK MANAGEMENT\n(NIBM), PUNE\nINDIA BANKING \nAND FINANCE  \nREPORT 2024\nEdited by\nPARTHA RAY\nARINDAM BANDYOPADHYAY\nSANJAY BASU\nINR 1495 (Ind sub)\nUS$ 79.95 (overseas)\nISBN 978-93-327-0655-2\nINR 2595 (Ind sub)\nUS$ 89.95 (overseas)\nNATIONAL INSTITUTE OF \nBANK MANAGEMENT\n(NIBM), PUNEwww.nibmindia.org\nNIBM\nPARTHA RAY\nARINDAM BANDYOPADHYAYSANJAY BASU\nI\nBFR has become the flagship annual publication of NIBM \nPune eagerly awaited by the practitioners, experts, regula-\ntors and students of financial services and insurance \nsector. IBFR 2024 has sixteen essays contributed primarily \nby the faculty and alumni of NIBM in collaboration with'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe InDesign CC 2017 (Windows)', 'creationdate': '2024-11-13T13:26:09+05:30', 'moddate': '2024-12-02T14:37:36+05:30', 'trapped': '/False', 'source': 'text', 'total_pages': 248, 'page': 0, 'page_label': 'i'}, page_content='by the faculty and alumni of NIBM in collaboration with \noutside experts wherever required covering aspects like \nmacroeconomy and financial markets, risk management, \ninformation technology and issues in HR and strategy… \nAll the sixteen essays have not only maintained the high \nacademic standards already set by the previous reports \nbut also improved the quality and rigour of analysis. It is a \nwelcome and timely addition to the growing literature on \nthe subject.\nRavindra H. Dholakia Member of Central Board of RBI;            \nformer Member of Monetary Policy Committee, RBI and Professor, \nIIM Ahmedabad. \nI\nBFR 2024 is a valuable compendium of articles on topi-\ncal issues in banking and finance. Its focus on the latest \ndevelopments and challenges in financial markets, risk'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe InDesign CC 2017 (Windows)', 'creationdate': '2024-11-13T13:26:09+05:30', 'moddate': '2024-12-02T14:37:36+05:30', 'trapped': '/False', 'source': 'text', 'total_pages': 248, 'page': 0, 'page_label': 'i'}, page_content='developments and challenges in financial markets, risk \nmanagement, digitalization, HR and strategy is commen-\ndable. It will be of immense benefit to academicians, \npractitioners and policymakers, in India and abroad.  \nBhimaraya Metri Director, IIM Nagpur\nT\nhe 2024 edition of IBFR is indeed a real treasure in the \nrealms of BFSI Research, Policy and Practice. It’s loaded \nwith insightful, analytical and sometimes intriguing posers \nto readers on a diverse range of topical issues—macro-\neconomy to financial sector, including insurance space and \nthe new normal in risk management to digital disruption. \nLatest development, such as, application of ECL mechanism \nand ESG framework also find a place in eruditely scripted \nfeatures. Another redeeming feature of such a priceless'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe InDesign CC 2017 (Windows)', 'creationdate': '2024-11-13T13:26:09+05:30', 'moddate': '2024-12-02T14:37:36+05:30', 'trapped': '/False', 'source': 'text', 'total_pages': 248, 'page': 0, 'page_label': 'i'}, page_content='features. Another redeeming feature of such a priceless \npublication relates to finer nuances of governance, well \nmanifested in the papers on penal action by supervisors, \nlearning from global bank failure and deft analysis of \nsomewhat off-beat embedded finance options... All in all, \nIBFR is truly readers’ privilege and BFSI’s pride!\nAtanu Kumar Das Director, Institute of Insurance and            \nRisk Management (IIRM), Hyderabad; former Managing Director \nand CEO, Bank of India\nI \nam pleased to see that NIBM has come out with its Annual \nBanking and Finance Report 2024. The issue carries well \nresearched articles by the faculty... and the scholarship is \nquite evident. I am sure that the banking fraternity would \nimmensely benefit from these well-articulated research'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe InDesign CC 2017 (Windows)', 'creationdate': '2024-11-13T13:26:09+05:30', 'moddate': '2024-12-02T14:37:36+05:30', 'trapped': '/False', 'source': 'text', 'total_pages': 248, 'page': 0, 'page_label': 'i'}, page_content='immensely benefit from these well-articulated research \npapers. … I am particularly happy that the rich volume \ncarries applied research papers on the emerging and critical \nissues like ESG, Dynamics of ECL, and Emerging Regulatory \nIssues… I strongly recommend it to be read by practitioners, \npolicy makers and students.  \nJustin C. McCarthy Chief Executive Officer, PRMIA \n(Professional Risk Managers’ International Association)\nT\nhe India Banking and Financial Report 2024 covers a \nrange of issues—from macro economy to performance \nof the credit guarantee schemes for MSMEs, cross border \nliquidity, risk management and HR that are of current \ninterest in BFSI sector. Besides this, the Report also is rich \nwith information and data that are analysed and reviewed')]

# %%
metadatas = [doc.metadata for doc in all_docs]
metadatas[:1]
# Out:
# [{'producer': 'Adobe PDF Library 15.0',
#   'creator': 'Adobe InDesign CC 2017 (Windows)',
#   'creationdate': '2024-11-13T13:26:09+05:30',
#   'moddate': '2024-12-02T14:37:36+05:30',
#   'trapped': '/False',
#   'source': 'text',
#   'total_pages': 248,
#   'page': 0,
#   'page_label': 'i'}]

# %%
# Ensure there are no None values in metadata
def clean_metadata(metadata):
    return {key: (value if value is not None else "") for key, value in metadata.items()}

# %%
from langchain.vectorstores import Chroma

vector_db = Chroma(persist_directory="indian_banking_fin_report_index", embedding_function=embeddings)

vector_db.add_texts(
    texts=[doc.page_content for doc in all_docs],
    metadatas=[clean_metadata(doc.metadata) for doc in all_docs]
)

vector_db.persist()
# Out:
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\514149717.py:3: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-chroma package and should be used instead. To use it run `pip install -U :class:`~langchain-chroma` and import as `from :class:`~langchain_chroma import Chroma``.
#   vector_db = Chroma(persist_directory="indian_banking_fin_report_index", embedding_function=embeddings)
# C:\Users\lalra\AppData\Local\Temp\ipykernel_19256\514149717.py:10: LangChainDeprecationWarning: Since Chroma 0.4.x the manual persistence method is no longer supported as docs are automatically persisted.
#   vector_db.persist()

# %% [markdown]
# ### Prompt Engineering

# %%
# from langchain.chat_models import ChatOpenAI
# llm = ChatOpenAI(temperature=0, model_name="gpt-3.5-turbo")

# %%
from langchain.retrievers.multi_query import MultiQueryRetriever

multi_query_retriever = MultiQueryRetriever.from_llm(
    retriever=vector_db.as_retriever(),
    llm=llm,
    include_original=True
)

# %%
# Utility to classify whether a query should use table or text data
def is_table_query(query: str) -> bool:
    table_keywords = ["table", "figure", "amount", "data", "statistics", "reserves", "value", "year", "percentage", "increase", "decrease"]
    return any(keyword.lower() in query.lower() for keyword in table_keywords)

# %%
def get_retriever(query: str):
    if is_table_query(query):
        return vector_db.as_retriever(search_kwargs={"filter": {"source": "table"}})
    else:
        return vector_db.as_retriever()

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.runnables.history import RunnableWithMessageHistory
from langchain_community.chat_message_histories import ChatMessageHistory
from langchain_core.output_parsers import StrOutputParser
from langchain.schema.runnable import RunnableMap

# template with memory placeholder
chat_prompt = ChatPromptTemplate.from_messages([
   ("system",  """You are an expert assistant trained on the India Banking and Finance Report (IBFR) 2024.
Always base your answers only on the given context.
Return exact values if mentioned, especially for numerical queries like inflation, growth rates, etc.
If the user's question has an answer in the context, quote it clearly.
If not, reply: "The report does not specify this."
"""),
   MessagesPlaceholder(variable_name="chat_history"),
   ("user", "Context:\n{context}\n\nQuestion: {input}")
])

parser = StrOutputParser()

# wrap your llm with prompt
context_chain = RunnableMap({
    "input": lambda x: x["input"],
    "chat_history": lambda x: x.get("chat_history", []),
    "context": lambda x: "\n\n".join(
        doc.page_content for doc in multi_query_retriever.invoke(x["input"])
    )
}) | chat_prompt | llm | parser

# %%
import redis
REDIS_URL = os.getenv('REDIS_HOST')
# Create a Redis client from the URL
r = redis.Redis.from_url(REDIS_URL, decode_responses=True)
try:
    # Test the connection
    r.set('foo', 'bar')
    print(r.get('foo'))  # Expected output: 'bar'
except Exception as e:
    print("Redis connection failed:", e)
# Out:
# bar

# %%
from langchain_community.chat_message_histories import RedisChatMessageHistory

# function provides Redis-based history based on session_id
def get_redis_history(session_id: str):
    return RedisChatMessageHistory(
        session_id=session_id,
        url=REDIS_URL
    )

# %%
runnable = RunnableWithMessageHistory(
    context_chain,
    get_redis_history,
    input_message_key="input",
    history_messages_key="chat_history"
)

# %%
def get_chat_response(user_input: str, session_id: str) -> str:
    """
    Invokes Langchain runnables with message history with user input and session id
    
    Args:
        user_input(str): The user's query or message
        session_id(str): Unique session identifier for tracking conversation history
    
    Returns:
        str: LLM-generated response
    """
    try:
        response = runnable.invoke(
            {"input": user_input},
            config={"configurable": {"session_id": session_id}}
        )
        return response
    except Exception as e:
        return f"An error occured {str(e)}"

# %%
response = get_chat_response("who is the Associate Professor of NIBM", "user_45d4")
print(response)
# Out:
# The Associate Professors at NIBM mentioned in the context are Richa Verma Bajaj, Shomi Srivastava, Smita Roy Trivedi, Tasneem Chherawala, Gargi Sanati, and Dipali Krishnakumar.

# %%
response = get_chat_response("what was the inflation in April 2022", "user_1")
print(response)
# Out:
# In April 2022, the CPI inflation peaked at 7.8% and the core CPI inflation peaked at 6.95%.

# %%
results = vector_db.similarity_search("Director of NIBM", k=3)
for doc in results:
    print(doc.page_content)
# Out:
# NIBM
#
#  Her research interests lie in interna-
# tional economics, central banking, foreign
# exchange market, macro prudential measures
# and technical analysis for markets
#
# Tarun Agarwal is Ex-Director, National Insur -
# ance Academy, Pune
#
# Tasneem Chherawala is Associate Professor at
# NIBM
#
#  Her domain expertise is in the areas of
# risk modelling and management, Basel, IFRS,
# financial derivatives, project finance and struc-
# tured finance, in which she conducts executive
# trainings and PGDM courses
# at NIBM
#
#  He is a Chartered Accountant with
# specialization in Audit, Compliance and Trade
# Finance
#
# Richa Verma Bajaj  is Associate Professor at
# NIBM
#
#  She has teaching, research and consult -
# ing experience of fifteen years in the area of
# Risk Management
#
# Shomi Srivastava  is Associate Professor at
# NIBM
#
#  His areas of specialization are Leader -
# ship, Human Resource Management, Discipline
# Management, Preventive Vigilance, Change
# Management and Organizational Develop-
# ment
#
# Shruti Nagar is Assistant Professor, National
# Insurance Academy, Pune
#
# Shyam Vansing Rathod is an alumnus of NIBM
# (PGDM 2022 – 24 batch)
#
# Smita Roy Trivedi  is Associate Professor at
# NIBM
#
#  Her research interests lie in interna-
# tional economics, central banking, foreign
# Finance
#
# Richa Verma Bajaj  is Associate Professor at
# NIBM
#
#  She has teaching, research and consult -
# ing experience of fifteen years in the area of
# Risk Management
#
# Shomi Srivastava  is Associate Professor at
# NIBM
#
#  His areas of specialization are Leader -
# ship, Human Resource Management, Discipline
# Management, Preventive Vigilance, Change
# Management and Organizational Develop-
# ment
#
# Shruti Nagar is Assistant Professor, National
# Insurance Academy, Pune
#
# Shyam Vansing Rathod is an alumnus of NIBM
# (PGDM 2022 – 24 batch)
#
# Smita Roy Trivedi  is Associate Professor at
# NIBM
#
#  Her research interests lie in interna-
# tional economics, central banking, foreign
# exchange market, macro prudential measures
# and technical analysis for markets
#
# Tarun Agarwal is Ex-Director, National Insur -
# ance Academy, Pune
#
# Tasneem Chherawala is Associate Professor at
# NIBM
#
#  Her domain expertise is in the areas of
# risk modelling and management, Basel, IFRS,
